# %% [markdown]
# # Library

# %%
pip install transformers datasets torch accelerate librosa numpy scikit-learn keras
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Collecting accelerate
#   Downloading accelerate-0.31.0-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.2.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests (from transformers)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.7 MB/s eta 0:00:00
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.0 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 43.7 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.11.4)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (4.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, pyarrow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, accelerate
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.
# Successfully installed accelerate-0.31.0 datasets-2.20.0 dill-0.3.8 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 pyarrow-16.1.0 requests-2.32.3 xxhash-3.4.1

# %%
# !kaggle datasets download -d mansourehk/shemo-persian-speech-emotion-detection-database
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mansourehk/shemo-persian-speech-emotion-detection-database
# License(s): unknown
# Downloading shemo-persian-speech-emotion-detection-database.zip to /content
#  99% 825M/829M [00:18<00:00, 39.2MB/s]
# 100% 829M/829M [00:18<00:00, 46.3MB/s]

# %%
# !unzip shemo-persian-speech-emotion-detection-database.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: transcript/final script/F24A22.tra
#   inflating: transcript/final script/F24A23.tra
#   inflating: transcript/final script/F24A24.tra
#   inflating: transcript/final script/F24A25.tra
#   inflating: transcript/final script/F24A26.tra
#   inflating: transcript/final script/F24A27.tra
#   inflating: transcript/final script/F24A28.tra
#   inflating: transcript/final script/F24A29.tra
#   inflating: transcript/final script/F24A30.tra
#   inflating: transcript/final script/F24A31.tra
#   inflating: transcript/final script/F24A32.tra
#   inflating: transcript/final script/F24A33.tra
#   inflating: transcript/final script/F24A34.tra
#   inflating: transcript/final script/F24A35.tra
#   inflating: transcript/final script/F24A36.tra
#   inflating: transcript/final script/F24A37.tra
#   inflating: transcript/final script/F24A38.tra
#   inflating: transcript/final script/F24A39.tra
#   inflating: transcript/final script/F24A40.tra
#   inflating: transcript/final script/F24A41.tra
#   inflating: transcript/final script/F24A42.tra
#   inflating: transcript/final script/F24A43.tra
#   inflating: transcript/final script/F24A44.tra
#   inflating: transcript/final script/F24A45.tra
#   inflating: transcript/final script/F24A46.tra
#   inflating: transcript/final script/F24A47.tra
#   inflating: transcript/final script/F24A48.tra
#   inflating: transcript/final script/F24A49.tra
#   inflating: transcript/final script/F24A50.tra
#   inflating: transcript/final script/F24A51.tra
#   inflating: transcript/final script/F24A52.tra
#   inflating: transcript/final script/F24A53.tra
#   inflating: transcript/final script/F24A54.tra
#   inflating: transcript/final script/F24A55.tra
#   inflating: transcript/final script/F24A56.tra
#   inflating: transcript/final script/F24A57.tra
#   inflating: transcript/final script/F24A58.tra
#   inflating: transcript/final script/F24A59.tra
#   inflating: transcript/final script/F24A60.tra
#   inflating: transcript/final script/F24A61.tra
#   inflating: transcript/final script/F24A62.tra
#   inflating: transcript/final script/F24A63.tra
#   inflating: transcript/final script/F24A64.tra
#   inflating: transcript/final script/F24A65.tra
#   inflating: transcript/final script/F24A66.tra
#   inflating: transcript/final script/F24A67.tra
#   inflating: transcript/final script/F24A68.tra
#   inflating: transcript/final script/F24A69.tra
#   inflating: transcript/final script/F24A70.tra
#   inflating: transcript/final script/F24F01.tra
#   inflating: transcript/final script/F24F02.tra
#   inflating: transcript/final script/F24F03.tra
#   inflating: transcript/final script/F24F04.tra
#   inflating: transcript/final script/F24H01.tra
#   inflating: transcript/final script/F24H02.tra
#   inflating: transcript/final script/F24H03.tra
#   inflating: transcript/final script/F24H04.tra
#   inflating: transcript/final script/F24H05.tra
#   inflating: transcript/final script/F24H06.tra
#   inflating: transcript/final script/F24H07.tra
#   inflating: transcript/final script/F24H08.tra
#   inflating: transcript/final script/F24H09.tra
#   inflating: transcript/final script/F24H10.tra
#   inflating: transcript/final script/F24H11.tra
#   inflating: transcript/final script/F24H12.tra
#   inflating: transcript/final script/F24H13.tra
#   inflating: transcript/final script/F24H14.tra
#   inflating: transcript/final script/F24H15.tra
#   inflating: transcript/final script/F24H16.tra
#   inflating: transcript/final script/F24H17.tra
#   inflating: transcript/final script/F24H18.tra
#   inflating: transcript/final script/F24H19.tra
#   inflating: transcript/final script/F24H20.tra
#   inflating: transcript/final script/F24H21.tra
#   inflating: transcript/final script/F24H22.tra
#   inflating: transcript/final script/F24H23.tra
#   inflating: transcript/final script/F24H24.tra
#   inflating: transcript/final script/F24H25.tra
#   inflating: transcript/final script/F24H26.tra
#   inflating: transcript/final script/F24H27.tra
#   inflating: transcript/final script/F24N01.tra
#   inflating: transcript/final script/F24N02.tra
#   inflating: transcript/final script/F24N03.tra
#   inflating: transcript/final script/F24N04.tra
#   inflating: transcript/final script/F24N05.tra
#   inflating: transcript/final script/F24N06.tra
#   inflating: transcript/final script/F24N07.tra
#   inflating: transcript/final script/F24N08.tra
#   inflating: transcript/final script/F24N09.tra
#   inflating: transcript/final script/F24N10.tra
#   inflating: transcript/final script/F24N11.tra
#   inflating: transcript/final script/F24N12.tra
#   inflating: transcript/final script/F24N13.tra
#   inflating: transcript/final script/F24N14.tra
#   inflating: transcript/final script/F24N15.tra
#   inflating: transcript/final script/F24N16.tra
#   inflating: transcript/final script/F24N17.tra
#   inflating: transcript/final script/F24N18.tra
#   inflating: transcript/final script/F24N19.tra
#   inflating: transcript/final script/F24N20.tra
#   inflating: transcript/final script/F24S01.tra
#   inflating: transcript/final script/F24S02.tra
#   inflating: transcript/final script/F24S03.tra
#   inflating: transcript/final script/F24S04.tra
#   inflating: transcript/final script/F24S05.tra
#   inflating: transcript/final script/F24S06.tra
#   inflating: transcript/final script/F24S07.tra
#   inflating: transcript/final script/F24S08.tra
#   inflating: transcript/final script/F24S09.tra
#   inflating: transcript/final script/F24S10.tra
#   inflating: transcript/final script/F24S11.tra
#   inflating: transcript/final script/F24S12.tra
#   inflating: transcript/final script/F24S13.tra
#   inflating: transcript/final script/F24S14.tra
#   inflating: transcript/final script/F24S15.tra
#   inflating: transcript/final script/F24W01.tra
#   inflating: transcript/final script/F24W02.tra
#   inflating: transcript/final script/F24W03.tra
#   inflating: transcript/final script/F24W04.tra
#   inflating: transcript/final script/F24W05.tra
#   inflating: transcript/final script/F24W06.tra
#   inflating: transcript/final script/F24W07.tra
#   inflating: transcript/final script/F24W08.tra
#   inflating: transcript/final script/F24W09.tra
#   inflating: transcript/final script/F24W10.tra
#   inflating: transcript/final script/F24W11.tra
#   inflating: transcript/final script/F24W12.tra
#   inflating: transcript/final script/F24W13.tra
#   inflating: transcript/final script/F24W14.tra
#   inflating: transcript/final script/F24W15.tra
#   inflating: transcript/final script/F24W16.tra
#   inflating: transcript/final script/F24W17.tra
#   inflating: transcript/final script/F24W18.tra
#   inflating: transcript/final script/F24W19.tra
#   inflating: transcript/final script/F24W20.tra
#   inflating: transcript/final script/F24W21.tra
#   inflating: transcript/final script/F24W22.tra
#   inflating: transcript/final script/F24W23.tra
#   inflating: transcript/final script/F24W24.tra
#   inflating: transcript/final script/F25A01.tra
#   inflating: transcript/final script/F25A02.tra
#   inflating: transcript/final script/F25A03.tra
#   inflating: transcript/final script/F25A04.tra
#   inflating: transcript/final script/F25A05.tra
#   inflating: transcript/final script/F25A06.tra
#   inflating: transcript/final script/F25A07.tra
#   inflating: transcript/final script/F25N01.tra
#   inflating: transcript/final script/F25N02.tra
#   inflating: transcript/final script/F25N03.tra
#   inflating: transcript/final script/F25N04.tra
#   inflating: transcript/final script/F26F01.tra
#   inflating: transcript/final script/F26N01.tra
#   inflating: transcript/final script/F26N02.tra
#   inflating: transcript/final script/F26N03.tra
#   inflating: transcript/final script/F26N04.tra
#   inflating: transcript/final script/F26N05.tra
#   inflating: transcript/final script/F26N06.tra
#   inflating: transcript/final script/F26S01.tra
#   inflating: transcript/final script/F26S02.tra
#   inflating: transcript/final script/F26S03.tra
#   inflating: transcript/final script/F27A01.tra
#   inflating: transcript/final script/F27A02.tra
#   inflating: transcript/final script/F27A03.tra
#   inflating: transcript/final script/F27H01.tra
#   inflating: transcript/final script/F27N01.tra
#   inflating: transcript/final script/F28A01.tra
#   inflating: transcript/final script/F28A02.tra
#   inflating: transcript/final script/F28A03.tra
#   inflating: transcript/final script/F28A04.tra
#   inflating: transcript/final script/F28A05.tra
#   inflating: transcript/final script/F28A06.tra
#   inflating: transcript/final script/F28A07.tra
#   inflating: transcript/final script/F28A08.tra
#   inflating: transcript/final script/F28A09.tra
#   inflating: transcript/final script/F28A10.tra
#   inflating: transcript/final script/F28A11.tra
#   inflating: transcript/final script/F28A12.tra
#   inflating: transcript/final script/F28A13.tra
#   inflating: transcript/final script/F28A14.tra
#   inflating: transcript/final script/F28A15.tra
#   inflating: transcript/final script/F28A16.tra
#   inflating: transcript/final script/F28A17.tra
#   inflating: transcript/final script/F28A18.tra
#   inflating: transcript/final script/F28A19.tra
#   inflating: transcript/final script/F28A20.tra
#   inflating: transcript/final script/F28A21.tra
#   inflating: transcript/final script/F28A22.tra
#   inflating: transcript/final script/F28A23.tra
#   inflating: transcript/final script/F28A24.tra
#   inflating: transcript/final script/F28A25.tra
#   inflating: transcript/final script/F28A26.tra
#   inflating: transcript/final script/F28H01.tra
#   inflating: transcript/final script/F28N01.tra
#   inflating: transcript/final script/F28N02.tra
#   inflating: transcript/final script/F28N03.tra
#   inflating: transcript/final script/F28N04.tra
#   inflating: transcript/final script/F28N05.tra
#   inflating: transcript/final script/F28N06.tra
#   inflating: transcript/final script/F28N07.tra
#   inflating: transcript/final script/F28S01.tra
#   inflating: transcript/final script/F28S02.tra
#   inflating: transcript/final script/F28S03.tra
#   inflating: transcript/final script/F28S04.tra
#   inflating: transcript/final script/F28S05.tra
#   inflating: transcript/final script/F28S06.tra
#   inflating: transcript/final script/F29H01.tra
#   inflating: transcript/final script/F29N01.tra
#   inflating: transcript/final script/F29N02.tra
#   inflating: transcript/final script/F29N03.tra
#   inflating: transcript/final script/F29N04.tra
#   inflating: transcript/final script/F29N05.tra
#   inflating: transcript/final script/F29N06.tra
#   inflating: transcript/final script/F29N07.tra
#   inflating: transcript/final script/F29N08.tra
#   inflating: transcript/final script/F29N09.tra
#   inflating: transcript/final script/F29N10.tra
#   inflating: transcript/final script/F29W01.tra
#   inflating: transcript/final script/F30A01.tra
#   inflating: transcript/final script/F30A02.tra
#   inflating: transcript/final script/F30A03.tra
#   inflating: transcript/final script/F30A04.tra
#   inflating: transcript/final script/F30A05.tra
#   inflating: transcript/final script/F30A06.tra
#   inflating: transcript/final script/F30A07.tra
#   inflating: transcript/final script/F30A08.tra
#   inflating: transcript/final script/F30F01.tra
#   inflating: transcript/final script/F30H01.tra
#   inflating: transcript/final script/F30H02.tra
#   inflating: transcript/final script/F30H03.tra
#   inflating: transcript/final script/F30H04.tra
#   inflating: transcript/final script/F30H05.tra
#   inflating: transcript/final script/F30H06.tra
#   inflating: transcript/final script/F30N01.tra
#   inflating: transcript/final script/F30N02.tra
#   inflating: transcript/final script/F30N03.tra
#   inflating: transcript/final script/F30N04.tra
#   inflating: transcript/final script/F30N05.tra
#   inflating: transcript/final script/F30N06.tra
#   inflating: transcript/final script/F30N07.tra
#   inflating: transcript/final script/F30N08.tra
#   inflating: transcript/final script/F30S01.tra
#   inflating: transcript/final script/F30S02.tra
#   inflating: transcript/final script/F30S03.tra
#   inflating: transcript/final script/F30S04.tra
#   inflating: transcript/final script/F30S05.tra
#   inflating: transcript/final script/F30S06.tra
#   inflating: transcript/final script/F30S07.tra
#   inflating: transcript/final script/F30S08.tra
#   inflating: transcript/final script/F30S09.tra
#   inflating: transcript/final script/F30S10.tra
#   inflating: transcript/final script/F30W01.tra
#   inflating: transcript/final script/F31A01.tra
#   inflating: transcript/final script/F31A02.tra
#   inflating: transcript/final script/F31A03.tra
#   inflating: transcript/final script/F31A04.tra
#   inflating: transcript/final script/F31A05.tra
#   inflating: transcript/final script/F31A06.tra
#   inflating: transcript/final script/F31A07.tra
#   inflating: transcript/final script/F31A08.tra
#   inflating: transcript/final script/F31A09.tra
#   inflating: transcript/final script/F31A10.tra
#   inflating: transcript/final script/F31A11.tra
#   inflating: transcript/final script/F31S01.tra
#   inflating: transcript/final script/M01H01.tra
#   inflating: transcript/final script/M01N01.tra
#   inflating: transcript/final script/M01N02.tra
#   inflating: transcript/final script/M01W01.tra
#   inflating: transcript/final script/M02A01.tra
#   inflating: transcript/final script/M02A02.tra
#   inflating: transcript/final script/M02A03.tra
#   inflating: transcript/final script/M02A04.tra
#   inflating: transcript/final script/M02A05.tra
#   inflating: transcript/final script/M02A06.tra
#   inflating: transcript/final script/M02A07.tra
#   inflating: transcript/final script/M02A08.tra
#   inflating: transcript/final script/M02A09.tra
#   inflating: transcript/final script/M02A10.tra
#   inflating: transcript/final script/M02A11.tra
#   inflating: transcript/final script/M02A12.tra
#   inflating: transcript/final script/M02A13.tra
#   inflating: transcript/final script/M02A14.tra
#   inflating: transcript/final script/M02A15.tra
#   inflating: transcript/final script/M02A16.tra
#   inflating: transcript/final script/M02A17.tra
#   inflating: transcript/final script/M02A18.tra
#   inflating: transcript/final script/M02A19.tra
#   inflating: transcript/final script/M02A20.tra
#   inflating: transcript/final script/M02A21.tra
#   inflating: transcript/final script/M02A22.tra
#   inflating: transcript/final script/M02A23.tra
#   inflating: transcript/final script/M02A24.tra
#   inflating: transcript/final script/M02A25.tra
#   inflating: transcript/final script/M02A26.tra
#   inflating: transcript/final script/M02A27.tra
#   inflating: transcript/final script/M02A28.tra
#   inflating: transcript/final script/M02H01.tra
#   inflating: transcript/final script/M02H02.tra
#   inflating: transcript/final script/M02H03.tra
#   inflating: transcript/final script/M02H04.tra
#   inflating: transcript/final script/M02N01.tra
#   inflating: transcript/final script/M02N02.tra
#   inflating: transcript/final script/M02N03.tra
#   inflating: transcript/final script/M02N04.tra
#   inflating: transcript/final script/M02N05.tra
#   inflating: transcript/final script/M02N06.tra
#   inflating: transcript/final script/M02N07.tra
#   inflating: transcript/final script/M02N08.tra
#   inflating: transcript/final script/M02N09.tra
#   inflating: transcript/final script/M02N10.tra
#   inflating: transcript/final script/M02N11.tra
#   inflating: transcript/final script/M02N12.tra
#   inflating: transcript/final script/M02N13.tra
#   inflating: transcript/final script/M02N14.tra
#   inflating: transcript/final script/M02N15.tra
#   inflating: transcript/final script/M02N16.tra
#   inflating: transcript/final script/M02N17.tra
#   inflating: transcript/final script/M02N18.tra
#   inflating: transcript/final script/M02N19.tra
#   inflating: transcript/final script/M02S01.tra
#   inflating: transcript/final script/M02S02.tra
#   inflating: transcript/final script/M03A01.tra
#   inflating: transcript/final script/M03A02.tra
#   inflating: transcript/final script/M03A03.tra
#   inflating: transcript/final script/M03A04.tra
#   inflating: transcript/final script/M03A05.tra
#   inflating: transcript/final script/M03A06.tra
#   inflating: transcript/final script/M03A07.tra
#   inflating: transcript/final script/M03A08.tra
#   inflating: transcript/final script/M03A09.tra
#   inflating: transcript/final script/M03A10.tra
#   inflating: transcript/final script/M03A11.tra
#   inflating: transcript/final script/M03A12.tra
#   inflating: transcript/final script/M03A13.tra
#   inflating: transcript/final script/M03A14.tra
#   inflating: transcript/final script/M03A15.tra
#   inflating: transcript/final script/M03A16.tra
#   inflating: transcript/final script/M03A17.tra
#   inflating: transcript/final script/M03A18.tra
#   inflating: transcript/final script/M03A19.tra
#   inflating: transcript/final script/M03A20.tra
#   inflating: transcript/final script/M03A21.tra
#   inflating: transcript/final script/M03A22.tra
#   inflating: transcript/final script/M03A23.tra
#   inflating: transcript/final script/M03A24.tra
#   inflating: transcript/final script/M03A25.tra
#   inflating: transcript/final script/M03A26.tra
#   inflating: transcript/final script/M03A27.tra
#   inflating: transcript/final script/M03A28.tra
#   inflating: transcript/final script/M03A29.tra
#   inflating: transcript/final script/M03A30.tra
#   inflating: transcript/final script/M03A31.tra
#   inflating: transcript/final script/M03A32.tra
#   inflating: transcript/final script/M03A33.tra
#   inflating: transcript/final script/M03A34.tra
#   inflating: transcript/final script/M03A35.tra
#   inflating: transcript/final script/M03A36.tra
#   inflating: transcript/final script/M03A37.tra
#   inflating: transcript/final script/M03A38.tra
#   inflating: transcript/final script/M03A39.tra
#   inflating: transcript/final script/M03A40.tra
#   inflating: transcript/final script/M03A41.tra
#   inflating: transcript/final script/M03A42.tra
#   inflating: transcript/final script/M03A43.tra
#   inflating: transcript/final script/M03A44.tra
#   inflating: transcript/final script/M03A45.tra
#   inflating: transcript/final script/M03A46.tra
#   inflating: transcript/final script/M03A47.tra
#   inflating: transcript/final script/M03A48.tra
#   inflating: transcript/final script/M03A49.tra
#   inflating: transcript/final script/M03F01.tra
#   inflating: transcript/final script/M03F02.tra
#   inflating: transcript/final script/M03H01.tra
#   inflating: transcript/final script/M03H02.tra
#   inflating: transcript/final script/M03N01.tra
#   inflating: transcript/final script/M03N02.tra
#   inflating: transcript/final script/M03N03.tra
#   inflating: transcript/final script/M03N04.tra
#   inflating: transcript/final script/M03N05.tra
#   inflating: transcript/final script/M03N06.tra
#   inflating: transcript/final script/M03N07.tra
#   inflating: transcript/final script/M03N08.tra
#   inflating: transcript/final script/M03N09.tra
#   inflating: transcript/final script/M03S01.tra
#   inflating: transcript/final script/M03S02.tra
#   inflating: transcript/final script/M03S03.tra
#   inflating: transcript/final script/M03S04.tra
#   inflating: transcript/final script/M03S05.tra
#   inflating: transcript/final script/M03S06.tra
#   inflating: transcript/final script/M03S07.tra
#   inflating: transcript/final script/M03S08.tra
#   inflating: transcript/final script/M03S09.tra
#   inflating: transcript/final script/M03S10.tra
#   inflating: transcript/final script/M03S11.tra
#   inflating: transcript/final script/M03S12.tra
#   inflating: transcript/final script/M03S13.tra
#   inflating: transcript/final script/M03S14.tra
#   inflating: transcript/final script/M03S15.tra
#   inflating: transcript/final script/M03S16.tra
#   inflating: transcript/final script/M03S17.tra
#   inflating: transcript/final script/M03S18.tra
#   inflating: transcript/final script/M03S19.tra
#   inflating: transcript/final script/M03S20.tra
#   inflating: transcript/final script/M03W01.tra
#   inflating: transcript/final script/M03W02.tra
#   inflating: transcript/final script/M03W03.tra
#   inflating: transcript/final script/M03W04.tra
#   inflating: transcript/final script/M03W05.tra
#   inflating: transcript/final script/M03W06.tra
#   inflating: transcript/final script/M03W07.tra
#   inflating: transcript/final script/M04A01.tra
#   inflating: transcript/final script/M04A02.tra
#   inflating: transcript/final script/M04A03.tra
#   inflating: transcript/final script/M04A04.tra
#   inflating: transcript/final script/M04A05.tra
#   inflating: transcript/final script/M04A06.tra
#   inflating: transcript/final script/M04A07.tra
#   inflating: transcript/final script/M04A08.tra
#   inflating: transcript/final script/M04A09.tra
#   inflating: transcript/final script/M04A10.tra
#   inflating: transcript/final script/M04A11.tra
#   inflating: transcript/final script/M04A12.tra
#   inflating: transcript/final script/M04H01.tra
#   inflating: transcript/final script/M04H02.tra
#   inflating: transcript/final script/M04N01.tra
#   inflating: transcript/final script/M04N02.tra
#   inflating: transcript/final script/M04N03.tra
#   inflating: transcript/final script/M04N04.tra
#   inflating: transcript/final script/M04N05.tra
#   inflating: transcript/final script/M04N06.tra
#   inflating: transcript/final script/M04N07.tra
#   inflating: transcript/final script/M04N08.tra
#   inflating: transcript/final script/M04N09.tra
#   inflating: transcript/final script/M04N10.tra
#   inflating: transcript/final script/M04N11.tra
#   inflating: transcript/final script/M04N12.tra
#   inflating: transcript/final script/M04N13.tra
#   inflating: transcript/final script/M04N14.tra
#   inflating: transcript/final script/M04N15.tra
#   inflating: transcript/final script/M04N16.tra
#   inflating: transcript/final script/M04N17.tra
#   inflating: transcript/final script/M04N18.tra
#   inflating: transcript/final script/M04N19.tra
#   inflating: transcript/final script/M04N20.tra
#   inflating: transcript/final script/M04N21.tra
#   inflating: transcript/final script/M04N22.tra
#   inflating: transcript/final script/M04N23.tra
#   inflating: transcript/final script/M04N24.tra
#   inflating: transcript/final script/M04N25.tra
#   inflating: transcript/final script/M04N26.tra
#   inflating: transcript/final script/M04N27.tra
#   inflating: transcript/final script/M04N28.tra
#   inflating: transcript/final script/M04N29.tra
#   inflating: transcript/final script/M04N30.tra
#   inflating: transcript/final script/M04N31.tra
#   inflating: transcript/final script/M04N32.tra
#   inflating: transcript/final script/M04N33.tra
#   inflating: transcript/final script/M04N34.tra
#   inflating: transcript/final script/M04N35.tra
#   inflating: transcript/final script/M04N36.tra
#   inflating: transcript/final script/M04N37.tra
#   inflating: transcript/final script/M04N38.tra
#   inflating: transcript/final script/M04N39.tra
#   inflating: transcript/final script/M04N40.tra
#   inflating: transcript/final script/M04N41.tra
#   inflating: transcript/final script/M04N42.tra
#   inflating: transcript/final script/M04N43.tra
#   inflating: transcript/final script/M04N44.tra
#   inflating: transcript/final script/M04N45.tra
#   inflating: transcript/final script/M04N46.tra
#   inflating: transcript/final script/M04N47.tra
#   inflating: transcript/final script/M04N48.tra
#   inflating: transcript/final script/M04N49.tra
#   inflating: transcript/final script/M04N50.tra
#   inflating: transcript/final script/M04N51.tra
#   inflating: transcript/final script/M04N52.tra
#   inflating: transcript/final script/M04N53.tra
#   inflating: transcript/final script/M04N54.tra
#   inflating: transcript/final script/M04N55.tra
#   inflating: transcript/final script/M04N56.tra
#   inflating: transcript/final script/M04N57.tra
#   inflating: transcript/final script/M04N58.tra
#   inflating: transcript/final script/M04N59.tra
#   inflating: transcript/final script/M04N60.tra
#   inflating: transcript/final script/M04N61.tra
#   inflating: transcript/final script/M04N62.tra
#   inflating: transcript/final script/M04N63.tra
#   inflating: transcript/final script/M04N64.tra
#   inflating: transcript/final script/M04N65.tra
#   inflating: transcript/final script/M04N66.tra
#   inflating: transcript/final script/M04N67.tra
#   inflating: transcript/final script/M04N68.tra
#   inflating: transcript/final script/M04N69.tra
#   inflating: transcript/final script/M04N70.tra
#   inflating: transcript/final script/M04N71.tra
#   inflating: transcript/final script/M04N72.tra
#   inflating: transcript/final script/M04N73.tra
#   inflating: transcript/final script/M04N74.tra
#   inflating: transcript/final script/M04N75.tra
#   inflating: transcript/final script/M04N76.tra
#   inflating: transcript/final script/M04N77.tra
#   inflating: transcript/final script/M04N78.tra
#   inflating: transcript/final script/M04N79.tra
#   inflating: transcript/final script/M04N80.tra
#   inflating: transcript/final script/M04N81.tra
#   inflating: transcript/final script/M04N82.tra
#   inflating: transcript/final script/M04S01.tra
#   inflating: transcript/final script/M04S02.tra
#   inflating: transcript/final script/M04S03.tra
#   inflating: transcript/final script/M04S04.tra
#   inflating: transcript/final script/M04S05.tra
#   inflating: transcript/final script/M04S06.tra
#   inflating: transcript/final script/M04S07.tra
#   inflating: transcript/final script/M04S08.tra
#   inflating: transcript/final script/M04S09.tra
#   inflating: transcript/final script/M04W01.tra
#   inflating: transcript/final script/M04W02.tra
#   inflating: transcript/final script/M05A01.tra
#   inflating: transcript/final script/M05A02.tra
#   inflating: transcript/final script/M05A03.tra
#   inflating: transcript/final script/M05A04.tra
#   inflating: transcript/final script/M05A05.tra
#   inflating: transcript/final script/M05A06.tra
#   inflating: transcript/final script/M05A07.tra
#   inflating: transcript/final script/M05A08.tra
#   inflating: transcript/final script/M05A09.tra
#   inflating: transcript/final script/M05A10.tra
#   inflating: transcript/final script/M05A11.tra
#   inflating: transcript/final script/M05A14.tra
#   inflating: transcript/final script/M05A15.tra
#   inflating: transcript/final script/M05F01.tra
#   inflating: transcript/final script/M05H01.tra
#   inflating: transcript/final script/M05H02.tra
#   inflating: transcript/final script/M05N01.tra
#   inflating: transcript/final script/M05N02.tra
#   inflating: transcript/final script/M05N03.tra
#   inflating: transcript/final script/M05N04.tra
#   inflating: transcript/final script/M05N11.tra
#   inflating: transcript/final script/M05N12.tra
#   inflating: transcript/final script/M05N13.tra
#   inflating: transcript/final script/M05N14.tra
#   inflating: transcript/final script/M05N15.tra
#   inflating: transcript/final script/M05N16.tra
#   inflating: transcript/final script/M05N17.tra
#   inflating: transcript/final script/M05N18.tra
#   inflating: transcript/final script/M05N19.tra
#   inflating: transcript/final script/M05N20.tra
#   inflating: transcript/final script/M05N21.tra
#   inflating: transcript/final script/M05N22.tra
#   inflating: transcript/final script/M05N23.tra
#   inflating: transcript/final script/M05N24.tra
#   inflating: transcript/final script/M05N25.tra
#   inflating: transcript/final script/M05N26.tra
#   inflating: transcript/final script/M05S01.tra
#   inflating: transcript/final script/M05S02.tra
#   inflating: transcript/final script/M05S03.tra
#   inflating: transcript/final script/M05S04.tra
#   inflating: transcript/final script/M05S05.tra
#   inflating: transcript/final script/M05S06.tra
#   inflating: transcript/final script/M05S07.tra
#   inflating: transcript/final script/M05S08.tra
#   inflating: transcript/final script/M05S09.tra
#   inflating: transcript/final script/M05S10.tra
#   inflating: transcript/final script/M05S11.tra
#   inflating: transcript/final script/M05S12.tra
#   inflating: transcript/final script/M05S13.tra
#   inflating: transcript/final script/M05S21.tra
#   inflating: transcript/final script/M05W01.tra
#   inflating: transcript/final script/M05W02.tra
#   inflating: transcript/final script/M05W04.tra
#   inflating: transcript/final script/M06A01.tra
#   inflating: transcript/final script/M06A02.tra
#   inflating: transcript/final script/M06N01.tra
#   inflating: transcript/final script/M06N02.tra
#   inflating: transcript/final script/M06N03.tra
#   inflating: transcript/final script/M06N04.tra
#   inflating: transcript/final script/M06N05.tra
#   inflating: transcript/final script/M06N06.tra
#   inflating: transcript/final script/M06S01.tra
#   inflating: transcript/final script/M06S02.tra
#   inflating: transcript/final script/M06S03.tra
#   inflating: transcript/final script/M06S04.tra
#   inflating: transcript/final script/M06S05.tra
#   inflating: transcript/final script/M06S06.tra
#   inflating: transcript/final script/M06S07.tra
#   inflating: transcript/final script/M06W01.tra
#   inflating: transcript/final script/M07F01.tra
#   inflating: transcript/final script/M07F02.tra
#   inflating: transcript/final script/M07F03.tra
#   inflating: transcript/final script/M07F04.tra
#   inflating: transcript/final script/M07F05.tra
#   inflating: transcript/final script/M07H01.tra
#   inflating: transcript/final script/M07H02.tra
#   inflating: transcript/final script/M07N01.tra
#   inflating: transcript/final script/M07N02.tra
#   inflating: transcript/final script/M07N03.tra
#   inflating: transcript/final script/M07N04.tra
#   inflating: transcript/final script/M07N05.tra
#   inflating: transcript/final script/M07N06.tra
#   inflating: transcript/final script/M07N07.tra
#   inflating: transcript/final script/M07N08.tra
#   inflating: transcript/final script/M07S01.tra
#   inflating: transcript/final script/M07W01.tra
#   inflating: transcript/final script/M08H01.tra
#   inflating: transcript/final script/M08H02.tra
#   inflating: transcript/final script/M08H03.tra
#   inflating: transcript/final script/M08H04.tra
#   inflating: transcript/final script/M08N01.tra
#   inflating: transcript/final script/M08N02.tra
#   inflating: transcript/final script/M08N03.tra
#   inflating: transcript/final script/M08N04.tra
#   inflating: transcript/final script/M08N05.tra
#   inflating: transcript/final script/M08N06.tra
#   inflating: transcript/final script/M08N07.tra
#   inflating: transcript/final script/M08N08.tra
#   inflating: transcript/final script/M08N09.tra
#   inflating: transcript/final script/M08N10.tra
#   inflating: transcript/final script/M08N11.tra
#   inflating: transcript/final script/M08S01.tra
#   inflating: transcript/final script/M09A01.tra
#   inflating: transcript/final script/M09A02.tra
#   inflating: transcript/final script/M09A03.tra
#   inflating: transcript/final script/M09A04.tra
#   inflating: transcript/final script/M09A05.tra
#   inflating: transcript/final script/M09A06.tra
#   inflating: transcript/final script/M09A07.tra
#   inflating: transcript/final script/M09A08.tra
#   inflating: transcript/final script/M09A09.tra
#   inflating: transcript/final script/M09A10.tra
#   inflating: transcript/final script/M09A11.tra
#   inflating: transcript/final script/M09A12.tra
#   inflating: transcript/final script/M09A13.tra
#   inflating: transcript/final script/M09A14.tra
#   inflating: transcript/final script/M09A15.tra
#   inflating: transcript/final script/M09A16.tra
#   inflating: transcript/final script/M09A17.tra
#   inflating: transcript/final script/M09A18.tra
#   inflating: transcript/final script/M09A19.tra
#   inflating: transcript/final script/M09A20.tra
#   inflating: transcript/final script/M09A21.tra
#   inflating: transcript/final script/M09A22.tra
#   inflating: transcript/final script/M09A23.tra
#   inflating: transcript/final script/M09N01.tra
#   inflating: transcript/final script/M09N02.tra
#   inflating: transcript/final script/M09N03.tra
#   inflating: transcript/final script/M10A01.tra
#   inflating: transcript/final script/M10A02.tra
#   inflating: transcript/final script/M10F01.tra
#   inflating: transcript/final script/M10N01.tra
#   inflating: transcript/final script/M11H01.tra
#   inflating: transcript/final script/M11H02.tra
#   inflating: transcript/final script/M11H03.tra
#   inflating: transcript/final script/M11H04.tra
#   inflating: transcript/final script/M11H05.tra
#   inflating: transcript/final script/M11H06.tra
#   inflating: transcript/final script/M11H07.tra
#   inflating: transcript/final script/M11H08.tra
#   inflating: transcript/final script/M11H09.tra
#   inflating: transcript/final script/M11N01.tra
#   inflating: transcript/final script/M11N02.tra
#   inflating: transcript/final script/M11N03.tra
#   inflating: transcript/final script/M11N04.tra
#   inflating: transcript/final script/M11N05.tra
#   inflating: transcript/final script/M11N06.tra
#   inflating: transcript/final script/M11S01.tra
#   inflating: transcript/final script/M12A01.tra
#   inflating: transcript/final script/M12A02.tra
#   inflating: transcript/final script/M12A03.tra
#   inflating: transcript/final script/M12A04.tra
#   inflating: transcript/final script/M12A05.tra
#   inflating: transcript/final script/M12A06.tra
#   inflating: transcript/final script/M12A07.tra
#   inflating: transcript/final script/M12A08.tra
#   inflating: transcript/final script/M12A09.tra
#   inflating: transcript/final script/M12A10.tra
#   inflating: transcript/final script/M12A11.tra
#   inflating: transcript/final script/M12A12.tra
#   inflating: transcript/final script/M12A13.tra
#   inflating: transcript/final script/M12A14.tra
#   inflating: transcript/final script/M12A15.tra
#   inflating: transcript/final script/M12A16.tra
#   inflating: transcript/final script/M12A17.tra
#   inflating: transcript/final script/M12A18.tra
#   inflating: transcript/final script/M12A19.tra
#   inflating: transcript/final script/M12A20.tra
#   inflating: transcript/final script/M12A21.tra
#   inflating: transcript/final script/M12A22.tra
#   inflating: transcript/final script/M12A23.tra
#   inflating: transcript/final script/M12A24.tra
#   inflating: transcript/final script/M12A25.tra
#   inflating: transcript/final script/M12A26.tra
#   inflating: transcript/final script/M12A27.tra
#   inflating: transcript/final script/M12A28.tra
#   inflating: transcript/final script/M12A29.tra
#   inflating: transcript/final script/M12A30.tra
#   inflating: transcript/final script/M12A31.tra
#   inflating: transcript/final script/M12A32.tra
#   inflating: transcript/final script/M12A33.tra
#   inflating: transcript/final script/M12A34.tra
#   inflating: transcript/final script/M12A35.tra
#   inflating: transcript/final script/M12A36.tra
#   inflating: transcript/final script/M12A37.tra
#   inflating: transcript/final script/M12A38.tra
#   inflating: transcript/final script/M12A39.tra
#   inflating: transcript/final script/M12A40.tra
#   inflating: transcript/final script/M12A41.tra
#   inflating: transcript/final script/M12A42.tra
#   inflating: transcript/final script/M12A43.tra
#   inflating: transcript/final script/M12A44.tra
#   inflating: transcript/final script/M12A45.tra
#   inflating: transcript/final script/M12A46.tra
#   inflating: transcript/final script/M12A47.tra
#   inflating: transcript/final script/M12A48.tra
#   inflating: transcript/final script/M12A49.tra
#   inflating: transcript/final script/M12A50.tra
#   inflating: transcript/final script/M12A51.tra
#   inflating: transcript/final script/M12A52.tra
#   inflating: transcript/final script/M12A53.tra
#   inflating: transcript/final script/M12A54.tra
#   inflating: transcript/final script/M12A55.tra
#   inflating: transcript/final script/M12A56.tra
#   inflating: transcript/final script/M12A57.tra
#   inflating: transcript/final script/M12A58.tra
#   inflating: transcript/final script/M12A59.tra
#   inflating: transcript/final script/M12A60.tra
#   inflating: transcript/final script/M12A61.tra
#   inflating: transcript/final script/M12A62.tra
#   inflating: transcript/final script/M12A63.tra
#   inflating: transcript/final script/M12A64.tra
#   inflating: transcript/final script/M12A65.tra
#   inflating: transcript/final script/M12A66.tra
#   inflating: transcript/final script/M12A67.tra
#   inflating: transcript/final script/M12A68.tra
#   inflating: transcript/final script/M12A69.tra
#   inflating: transcript/final script/M12H01.tra
#   inflating: transcript/final script/M12N01.tra
#   inflating: transcript/final script/M12N02.tra
#   inflating: transcript/final script/M12N03.tra
#   inflating: transcript/final script/M12N04.tra
#   inflating: transcript/final script/M12N05.tra
#   inflating: transcript/final script/M12N06.tra
#   inflating: transcript/final script/M12N07.tra
#   inflating: transcript/final script/M12N08.tra
#   inflating: transcript/final script/M12N09.tra
#   inflating: transcript/final script/M12N10.tra
#   inflating: transcript/final script/M12N11.tra
#   inflating: transcript/final script/M12N12.tra
#   inflating: transcript/final script/M12N13.tra
#   inflating: transcript/final script/M12N14.tra
#   inflating: transcript/final script/M12N15.tra
#   inflating: transcript/final script/M12N16.tra
#   inflating: transcript/final script/M12N17.tra
#   inflating: transcript/final script/M12N18.tra
#   inflating: transcript/final script/M12N19.tra
#   inflating: transcript/final script/M12N20.tra
#   inflating: transcript/final script/M12N21.tra
#   inflating: transcript/final script/M12N22.tra
#   inflating: transcript/final script/M12N23.tra
#   inflating: transcript/final script/M12N24.tra
#   inflating: transcript/final script/M12N25.tra
#   inflating: transcript/final script/M12N26.tra
#   inflating: transcript/final script/M12N27.tra
#   inflating: transcript/final script/M12N28.tra
#   inflating: transcript/final script/M12N29.tra
#   inflating: transcript/final script/M12N30.tra
#   inflating: transcript/final script/M12N31.tra
#   inflating: transcript/final script/M12N32.tra
#   inflating: transcript/final script/M12N33.tra
#   inflating: transcript/final script/M12N34.tra
#   inflating: transcript/final script/M12N35.tra
#   inflating: transcript/final script/M12N36.tra
#   inflating: transcript/final script/M12N37.tra
#   inflating: transcript/final script/M12N38.tra
#   inflating: transcript/final script/M12N39.tra
#   inflating: transcript/final script/M12N40.tra
#   inflating: transcript/final script/M12N41.tra
#   inflating: transcript/final script/M12N42.tra
#   inflating: transcript/final script/M12N43.tra
#   inflating: transcript/final script/M12N44.tra
#   inflating: transcript/final script/M12N45.tra
#   inflating: transcript/final script/M12N46.tra
#   inflating: transcript/final script/M12N47.tra
#   inflating: transcript/final script/M12N48.tra
#   inflating: transcript/final script/M12N49.tra
#   inflating: transcript/final script/M12N50.tra
#   inflating: transcript/final script/M12N51.tra
#   inflating: transcript/final script/M12N52.tra
#   inflating: transcript/final script/M12N53.tra
#   inflating: transcript/final script/M12N54.tra
#   inflating: transcript/final script/M12N55.tra
#   inflating: transcript/final script/M12N56.tra
#   inflating: transcript/final script/M12N57.tra
#   inflating: transcript/final script/M12N58.tra
#   inflating: transcript/final script/M12N59.tra
#   inflating: transcript/final script/M12N60.tra
#   inflating: transcript/final script/M12N61.tra
#   inflating: transcript/final script/M12N62.tra
#   inflating: transcript/final script/M12N63.tra
#   inflating: transcript/final script/M12N64.tra
#   inflating: transcript/final script/M12N65.tra
#   inflating: transcript/final script/M12N66.tra
#   inflating: transcript/final script/M12N67.tra
#   inflating: transcript/final script/M12N68.tra
#   inflating: transcript/final script/M12N69.tra
#   inflating: transcript/final script/M12N70.tra
#   inflating: transcript/final script/M12N71.tra
#   inflating: transcript/final script/M12N72.tra
#   inflating: transcript/final script/M12N73.tra
#   inflating: transcript/final script/M12N74.tra
#   inflating: transcript/final script/M12N75.tra
#   inflating: transcript/final script/M12N76.tra
#   inflating: transcript/final script/M12N77.tra
#   inflating: transcript/final script/M12N78.tra
#   inflating: transcript/final script/M12N79.tra
#   inflating: transcript/final script/M12N80.tra
#   inflating: transcript/final script/M12N81.tra
#   inflating: transcript/final script/M12N82.tra
#   inflating: transcript/final script/M12N83.tra
#   inflating: transcript/final script/M12N84.tra
#   inflating: transcript/final script/M12N85.tra
#   inflating: transcript/final script/M12N86.tra
#   inflating: transcript/final script/M12N87.tra
#   inflating: transcript/final script/M12N88.tra
#   inflating: transcript/final script/M12N89.tra
#   inflating: transcript/final script/M12N90.tra
#   inflating: transcript/final script/M12N91.tra
#   inflating: transcript/final script/M12N92.tra
#   inflating: transcript/final script/M12N93.tra
#   inflating: transcript/final script/M12N94.tra
#   inflating: transcript/final script/M12N95.tra
#   inflating: transcript/final script/M12N96.tra
#   inflating: transcript/final script/M12S01.tra
#   inflating: transcript/final script/M12S02.tra
#   inflating: transcript/final script/M12S03.tra
#   inflating: transcript/final script/M12S04.tra
#   inflating: transcript/final script/M12S05.tra
#   inflating: transcript/final script/M12W01.tra
#   inflating: transcript/final script/M12W02.tra
#   inflating: transcript/final script/M12W03.tra
#   inflating: transcript/final script/M12W04.tra
#   inflating: transcript/final script/M12W05.tra
#   inflating: transcript/final script/M12W06.tra
#   inflating: transcript/final script/M12W07.tra
#   inflating: transcript/final script/M12W08.tra
#   inflating: transcript/final script/M12W09.tra
#   inflating: transcript/final script/M13A01.tra
#   inflating: transcript/final script/M13H01.tra
#   inflating: transcript/final script/M13H02.tra
#   inflating: transcript/final script/M13H03.tra
#   inflating: transcript/final script/M13N01.tra
#   inflating: transcript/final script/M14N01.tra
#   inflating: transcript/final script/M14N02.tra
#   inflating: transcript/final script/M14N03.tra
#   inflating: transcript/final script/M14N04.tra
#   inflating: transcript/final script/M14N05.tra
#   inflating: transcript/final script/M14N06.tra
#   inflating: transcript/final script/M14S01.tra
#   inflating: transcript/final script/M15A01.tra
#   inflating: transcript/final script/M15A02.tra
#   inflating: transcript/final script/M15A03.tra
#   inflating: transcript/final script/M15A04.tra
#   inflating: transcript/final script/M15A05.tra
#   inflating: transcript/final script/M15A06.tra
#   inflating: transcript/final script/M15A07.tra
#   inflating: transcript/final script/M15A08.tra
#   inflating: transcript/final script/M15A09.tra
#   inflating: transcript/final script/M15A10.tra
#   inflating: transcript/final script/M15A11.tra
#   inflating: transcript/final script/M15A12.tra
#   inflating: transcript/final script/M15A13.tra
#   inflating: transcript/final script/M15N01.tra
#   inflating: transcript/final script/M15N02.tra
#   inflating: transcript/final script/M15N03.tra
#   inflating: transcript/final script/M15N04.tra
#   inflating: transcript/final script/M15W01.tra
#   inflating: transcript/final script/M16A01.tra
#   inflating: transcript/final script/M16A02.tra
#   inflating: transcript/final script/M16A03.tra
#   inflating: transcript/final script/M16A04.tra
#   inflating: transcript/final script/M16A05.tra
#   inflating: transcript/final script/M16A06.tra
#   inflating: transcript/final script/M16A07.tra
#   inflating: transcript/final script/M16A08.tra
#   inflating: transcript/final script/M16A09.tra
#   inflating: transcript/final script/M16A10.tra
#   inflating: transcript/final script/M16A11.tra
#   inflating: transcript/final script/M16A12.tra
#   inflating: transcript/final script/M16A13.tra
#   inflating: transcript/final script/M16A14.tra
#   inflating: transcript/final script/M16A15.tra
#   inflating: transcript/final script/M16A16.tra
#   inflating: transcript/final script/M16A17.tra
#   inflating: transcript/final script/M16A18.tra
#   inflating: transcript/final script/M16A19.tra
#   inflating: transcript/final script/M16A20.tra
#   inflating: transcript/final script/M16A21.tra
#   inflating: transcript/final script/M16A22.tra
#   inflating: transcript/final script/M16A23.tra
#   inflating: transcript/final script/M16A24.tra
#   inflating: transcript/final script/M16A25.tra
#   inflating: transcript/final script/M16A26.tra
#   inflating: transcript/final script/M16A27.tra
#   inflating: transcript/final script/M16A28.tra
#   inflating: transcript/final script/M16A29.tra
#   inflating: transcript/final script/M16A30.tra
#   inflating: transcript/final script/M16A31.tra
#   inflating: transcript/final script/M16A32.tra
#   inflating: transcript/final script/M16A33.tra
#   inflating: transcript/final script/M16F01.tra
#   inflating: transcript/final script/M16H01.tra
#   inflating: transcript/final script/M16H02.tra
#   inflating: transcript/final script/M16H03.tra
#   inflating: transcript/final script/M16H04.tra
#   inflating: transcript/final script/M16H05.tra
#   inflating: transcript/final script/M16H06.tra
#   inflating: transcript/final script/M16H07.tra
#   inflating: transcript/final script/M16H08.tra
#   inflating: transcript/final script/M16N01.tra
#   inflating: transcript/final script/M16N02.tra
#   inflating: transcript/final script/M16N03.tra
#   inflating: transcript/final script/M16N04.tra
#   inflating: transcript/final script/M16N05.tra
#   inflating: transcript/final script/M16W01.tra
#   inflating: transcript/final script/M16W02.tra
#   inflating: transcript/final script/M17A01.tra
#   inflating: transcript/final script/M17H01.tra
#   inflating: transcript/final script/M17N01.tra
#   inflating: transcript/final script/M17N02.tra
#   inflating: transcript/final script/M17N03.tra
#   inflating: transcript/final script/M17N04.tra
#   inflating: transcript/final script/M17N05.tra
#   inflating: transcript/final script/M17N06.tra
#   inflating: transcript/final script/M17N07.tra
#   inflating: transcript/final script/M17N08.tra
#   inflating: transcript/final script/M17N09.tra
#   inflating: transcript/final script/M17S01.tra
#   inflating: transcript/final script/M17W01.tra
#   inflating: transcript/final script/M18A01.tra
#   inflating: transcript/final script/M18N01.tra
#   inflating: transcript/final script/M18N02.tra
#   inflating: transcript/final script/M18N03.tra
#   inflating: transcript/final script/M18N04.tra
#   inflating: transcript/final script/M18N05.tra
#   inflating: transcript/final script/M18N06.tra
#   inflating: transcript/final script/M18N07.tra
#   inflating: transcript/final script/M18N08.tra
#   inflating: transcript/final script/M18N09.tra
#   inflating: transcript/final script/M18N10.tra
#   inflating: transcript/final script/M18N11.tra
#   inflating: transcript/final script/M18N12.tra
#   inflating: transcript/final script/M18N13.tra
#   inflating: transcript/final script/M18N14.tra
#   inflating: transcript/final script/M18N15.tra
#   inflating: transcript/final script/M18N16.tra
#   inflating: transcript/final script/M18N17.tra
#   inflating: transcript/final script/M18S01.tra
#   inflating: transcript/final script/M19A01.tra
#   inflating: transcript/final script/M19A02.tra
#   inflating: transcript/final script/M19A03.tra
# ...
#   inflating: transcript/final text/M41H03.ort
#   inflating: transcript/final text/M41H04.ort
#   inflating: transcript/final text/M41H05.ort
#   inflating: transcript/final text/M41H06.ort
#   inflating: transcript/final text/M41H07.ort
#   inflating: transcript/final text/M41N01.ort
#   inflating: transcript/final text/M41N02.ort
#   inflating: transcript/final text/M41W01.ort
#   inflating: transcript/final text/M41W02.ort
#   inflating: transcript/final text/M41W03.ort
#   inflating: transcript/final text/M41W04.ort
#   inflating: transcript/final text/M41W05.ort
#   inflating: transcript/final text/M41W06.ort
#   inflating: transcript/final text/M41W07.ort
#   inflating: transcript/final text/M42A01.ort
#   inflating: transcript/final text/M42A02.ort
#   inflating: transcript/final text/M42A03.ort
#   inflating: transcript/final text/M42A04.ort
#   inflating: transcript/final text/M42A05.ort
#   inflating: transcript/final text/M42A06.ort
#   inflating: transcript/final text/M42A07.ort
#   inflating: transcript/final text/M42A08.ort
#   inflating: transcript/final text/M42A09.ort
#   inflating: transcript/final text/M42A10.ort
#   inflating: transcript/final text/M42A11.ort
#   inflating: transcript/final text/M42A12.ort
#   inflating: transcript/final text/M42A13.ort
#   inflating: transcript/final text/M42N01.ort
#   inflating: transcript/final text/M43A01.ort
#   inflating: transcript/final text/M43A02.ort
#   inflating: transcript/final text/M43A03.ort
#   inflating: transcript/final text/M43A04.ort
#   inflating: transcript/final text/M43A05.ort
#   inflating: transcript/final text/M43A06.ort
#   inflating: transcript/final text/M43A07.ort
#   inflating: transcript/final text/M43A08.ort
#   inflating: transcript/final text/M43A09.ort
#   inflating: transcript/final text/M43A10.ort
#   inflating: transcript/final text/M43A11.ort
#   inflating: transcript/final text/M43A12.ort
#   inflating: transcript/final text/M43A13.ort
#   inflating: transcript/final text/M43A14.ort
#   inflating: transcript/final text/M43A15.ort
#   inflating: transcript/final text/M43A16.ort
#   inflating: transcript/final text/M43A17.ort
#   inflating: transcript/final text/M43H01.ort
#   inflating: transcript/final text/M43H02.ort
#   inflating: transcript/final text/M43H03.ort
#   inflating: transcript/final text/M43N01.ort
#   inflating: transcript/final text/M43N02.ort
#   inflating: transcript/final text/M43N03.ort
#   inflating: transcript/final text/M43N04.ort
#   inflating: transcript/final text/M43N05.ort
#   inflating: transcript/final text/M43N06.ort
#   inflating: transcript/final text/M43N07.ort
#   inflating: transcript/final text/M43N08.ort
#   inflating: transcript/final text/M43W01.ort
#   inflating: transcript/final text/M43W02.ort
#   inflating: transcript/final text/M43W03.ort
#   inflating: transcript/final text/M43W04.ort
#   inflating: transcript/final text/M43W05.ort
#   inflating: transcript/final text/M43W06.ort
#   inflating: transcript/final text/M43W07.ort
#   inflating: transcript/final text/M44A01.ort
#   inflating: transcript/final text/M44F01.ort
#   inflating: transcript/final text/M44H01.ort
#   inflating: transcript/final text/M44H02.ort
#   inflating: transcript/final text/M44H03.ort
#   inflating: transcript/final text/M44H04.ort
#   inflating: transcript/final text/M44H05.ort
#   inflating: transcript/final text/M44H06.ort
#   inflating: transcript/final text/M44H07.ort
#   inflating: transcript/final text/M44H08.ort
#   inflating: transcript/final text/M44H09.ort
#   inflating: transcript/final text/M44N01.ort
#   inflating: transcript/final text/M44N02.ort
#   inflating: transcript/final text/M44N03.ort
#   inflating: transcript/final text/M44N04.ort
#   inflating: transcript/final text/M44N05.ort
#   inflating: transcript/final text/M44N06.ort
#   inflating: transcript/final text/M44N07.ort
#   inflating: transcript/final text/M44N08.ort
#   inflating: transcript/final text/M44N09.ort
#   inflating: transcript/final text/M44N10.ort
#   inflating: transcript/final text/M44N11.ort
#   inflating: transcript/final text/M44N12.ort
#   inflating: transcript/final text/M44N13.ort
#   inflating: transcript/final text/M44N14.ort
#   inflating: transcript/final text/M44N15.ort
#   inflating: transcript/final text/M44N16.ort
#   inflating: transcript/final text/M44N17.ort
#   inflating: transcript/final text/M44N18.ort
#   inflating: transcript/final text/M44N19.ort
#   inflating: transcript/final text/M44N20.ort
#   inflating: transcript/final text/M44N21.ort
#   inflating: transcript/final text/M44N22.ort
#   inflating: transcript/final text/M44N23.ort
#   inflating: transcript/final text/M44N24.ort
#   inflating: transcript/final text/M44N25.ort
#   inflating: transcript/final text/M44N26.ort
#   inflating: transcript/final text/M44S01.ort
#   inflating: transcript/final text/M44S02.ort
#   inflating: transcript/final text/M44S03.ort
#   inflating: transcript/final text/M44S04.ort
#   inflating: transcript/final text/M44W01.ort
#   inflating: transcript/final text/M44W02.ort
#   inflating: transcript/final text/M44W03.ort
#   inflating: transcript/final text/M45N01.ort
#   inflating: transcript/final text/M45N02.ort
#   inflating: transcript/final text/M45N03.ort
#   inflating: transcript/final text/M45N04.ort
#   inflating: transcript/final text/M45N05.ort
#   inflating: transcript/final text/M45N06.ort
#   inflating: transcript/final text/M45W01.ort
#   inflating: transcript/final text/M46A01.ort
#   inflating: transcript/final text/M46A02.ort
#   inflating: transcript/final text/M46A03.ort
#   inflating: transcript/final text/M46A04.ort
#   inflating: transcript/final text/M46A05.ort
#   inflating: transcript/final text/M46N01.ort
#   inflating: transcript/final text/M46N02.ort
#   inflating: transcript/final text/M46N03.ort
#   inflating: transcript/final text/M46N04.ort
#   inflating: transcript/final text/M46N05.ort
#   inflating: transcript/final text/M46N06.ort
#   inflating: transcript/final text/M46N07.ort
#   inflating: transcript/final text/M46N08.ort
#   inflating: transcript/final text/M46N09.ort
#   inflating: transcript/final text/M46N10.ort
#   inflating: transcript/final text/M46N11.ort
#   inflating: transcript/final text/M46W01.ort
#   inflating: transcript/final text/M47A01.ort
#   inflating: transcript/final text/M47A02.ort
#   inflating: transcript/final text/M47A03.ort
#   inflating: transcript/final text/M47A04.ort
#   inflating: transcript/final text/M47A05.ort
#   inflating: transcript/final text/M47A06.ort
#   inflating: transcript/final text/M47A07.ort
#   inflating: transcript/final text/M47A08.ort
#   inflating: transcript/final text/M47A09.ort
#   inflating: transcript/final text/M47A10.ort
#   inflating: transcript/final text/M47A11.ort
#   inflating: transcript/final text/M47A12.ort
#   inflating: transcript/final text/M47A13.ort
#   inflating: transcript/final text/M47A14.ort
#   inflating: transcript/final text/M47A15.ort
#   inflating: transcript/final text/M47A16.ort
#   inflating: transcript/final text/M47A17.ort
#   inflating: transcript/final text/M47A18.ort
#   inflating: transcript/final text/M47A19.ort
#   inflating: transcript/final text/M47A20.ort
#   inflating: transcript/final text/M47H01.ort
#   inflating: transcript/final text/M47N01.ort
#   inflating: transcript/final text/M47N02.ort
#   inflating: transcript/final text/M47N03.ort
#   inflating: transcript/final text/M47N04.ort
#   inflating: transcript/final text/M47N05.ort
#   inflating: transcript/final text/M47N06.ort
#   inflating: transcript/final text/M47N07.ort
#   inflating: transcript/final text/M47N08.ort
#   inflating: transcript/final text/M47N09.ort
#   inflating: transcript/final text/M47N10.ort
#   inflating: transcript/final text/M47N11.ort
#   inflating: transcript/final text/M47N12.ort
#   inflating: transcript/final text/M47N13.ort
#   inflating: transcript/final text/M47N14.ort
#   inflating: transcript/final text/M47N15.ort
#   inflating: transcript/final text/M47N16.ort
#   inflating: transcript/final text/M47N17.ort
#   inflating: transcript/final text/M47N18.ort
#   inflating: transcript/final text/M47N19.ort
#   inflating: transcript/final text/M47N20.ort
#   inflating: transcript/final text/M47N21.ort
#   inflating: transcript/final text/M47N22.ort
#   inflating: transcript/final text/M47N23.ort
#   inflating: transcript/final text/M47N24.ort
#   inflating: transcript/final text/M47N25.ort
#   inflating: transcript/final text/M47N26.ort
#   inflating: transcript/final text/M47N27.ort
#   inflating: transcript/final text/M47W01.ort
#   inflating: transcript/final text/M47W02.ort
#   inflating: transcript/final text/M48A01.ort
#   inflating: transcript/final text/M48A02.ort
#   inflating: transcript/final text/M48A03.ort
#   inflating: transcript/final text/M48A04.ort
#   inflating: transcript/final text/M48N01.ort
#   inflating: transcript/final text/M48N02.ort
#   inflating: transcript/final text/M48N03.ort
#   inflating: transcript/final text/M48N04.ort
#   inflating: transcript/final text/M48N05.ort
#   inflating: transcript/final text/M48N06.ort
#   inflating: transcript/final text/M48N07.ort
#   inflating: transcript/final text/M48N08.ort
#   inflating: transcript/final text/M48N09.ort
#   inflating: transcript/final text/M48N10.ort
#   inflating: transcript/final text/M48N11.ort
#   inflating: transcript/final text/M48N12.ort
#   inflating: transcript/final text/M48S01.ort
#   inflating: transcript/final text/M48W01.ort
#   inflating: transcript/final text/M49H01.ort
#   inflating: transcript/final text/M49N01.ort
#   inflating: transcript/final text/M49N02.ort
#   inflating: transcript/final text/M49N03.ort
#   inflating: transcript/final text/M49N04.ort
#   inflating: transcript/final text/M49N05.ort
#   inflating: transcript/final text/M50A01.ort
#   inflating: transcript/final text/M50A02.ort
#   inflating: transcript/final text/M50A03.ort
#   inflating: transcript/final text/M50A04.ort
#   inflating: transcript/final text/M50A05.ort
#   inflating: transcript/final text/M50A06.ort
#   inflating: transcript/final text/M50A07.ort
#   inflating: transcript/final text/M50A08.ort
#   inflating: transcript/final text/M50A09.ort
#   inflating: transcript/final text/M50A10.ort
#   inflating: transcript/final text/M50A11.ort
#   inflating: transcript/final text/M50A12.ort
#   inflating: transcript/final text/M50N01.ort
#   inflating: transcript/final text/M50N02.ort
#   inflating: transcript/final text/M50N03.ort
#   inflating: transcript/final text/M51N01.ort
#   inflating: transcript/final text/M51N02.ort
#   inflating: transcript/final text/M51N03.ort
#   inflating: transcript/final text/M51N04.ort
#   inflating: transcript/final text/M51N05.ort
#   inflating: transcript/final text/M51N06.ort
#   inflating: transcript/final text/M51N07.ort
#   inflating: transcript/final text/M51N08.ort
#   inflating: transcript/final text/M51N09.ort
#   inflating: transcript/final text/M51N10.ort
#   inflating: transcript/final text/M51N11.ort
#   inflating: transcript/final text/M51N12.ort
#   inflating: transcript/final text/M51N13.ort
#   inflating: transcript/final text/M51N14.ort
#   inflating: transcript/final text/M51N15.ort
#   inflating: transcript/final text/M51N16.ort
#   inflating: transcript/final text/M51N17.ort
#   inflating: transcript/final text/M51N18.ort
#   inflating: transcript/final text/M51N19.ort
#   inflating: transcript/final text/M51N20.ort
#   inflating: transcript/final text/M51N21.ort
#   inflating: transcript/final text/M51N22.ort
#   inflating: transcript/final text/M51N23.ort
#   inflating: transcript/final text/M51N24.ort
#   inflating: transcript/final text/M51S01.ort
#   inflating: transcript/final text/M51S02.ort
#   inflating: transcript/final text/M52N01.ort
#   inflating: transcript/final text/M52N02.ort
#   inflating: transcript/final text/M52N03.ort
#   inflating: transcript/final text/M52S01.ort
#   inflating: transcript/final text/M52S02.ort
#   inflating: transcript/final text/M52S03.ort
#   inflating: transcript/final text/M52S04.ort
#   inflating: transcript/final text/M53A01.ort
#   inflating: transcript/final text/M53A02.ort
#   inflating: transcript/final text/M53A03.ort
#   inflating: transcript/final text/M53A04.ort
#   inflating: transcript/final text/M53A05.ort
#   inflating: transcript/final text/M53A06.ort
#   inflating: transcript/final text/M53A07.ort
#   inflating: transcript/final text/M53A08.ort
#   inflating: transcript/final text/M53A09.ort
#   inflating: transcript/final text/M53A10.ort
#   inflating: transcript/final text/M53A11.ort
#   inflating: transcript/final text/M53A12.ort
#   inflating: transcript/final text/M53A13.ort
#   inflating: transcript/final text/M53A14.ort
#   inflating: transcript/final text/M53A15.ort
#   inflating: transcript/final text/M53A16.ort
#   inflating: transcript/final text/M53A17.ort
#   inflating: transcript/final text/M53A18.ort
#   inflating: transcript/final text/M53A19.ort
#   inflating: transcript/final text/M53A20.ort
#   inflating: transcript/final text/M53A21.ort
#   inflating: transcript/final text/M53A22.ort
#   inflating: transcript/final text/M53A23.ort
#   inflating: transcript/final text/M53A24.ort
#   inflating: transcript/final text/M53A25.ort
#   inflating: transcript/final text/M53A26.ort
#   inflating: transcript/final text/M53A27.ort
#   inflating: transcript/final text/M53A28.ort
#   inflating: transcript/final text/M53N01.ort
#   inflating: transcript/final text/M53N02.ort
#   inflating: transcript/final text/M53N03.ort
#   inflating: transcript/final text/M53N04.ort
#   inflating: transcript/final text/M53N05.ort
#   inflating: transcript/final text/M53N06.ort
#   inflating: transcript/final text/M53N07.ort
#   inflating: transcript/final text/M53N08.ort
#   inflating: transcript/final text/M53N09.ort
#   inflating: transcript/final text/M53N10.ort
#   inflating: transcript/final text/M53N11.ort
#   inflating: transcript/final text/M53N12.ort
#   inflating: transcript/final text/M53N13.ort
#   inflating: transcript/final text/M53N14.ort
#   inflating: transcript/final text/M53N15.ort
#   inflating: transcript/final text/M53N16.ort
#   inflating: transcript/final text/M53N17.ort
#   inflating: transcript/final text/M53N18.ort
#   inflating: transcript/final text/M53N19.ort
#   inflating: transcript/final text/M53N20.ort
#   inflating: transcript/final text/M53N21.ort
#   inflating: transcript/final text/M53N22.ort
#   inflating: transcript/final text/M53N23.ort
#   inflating: transcript/final text/M53N24.ort
#   inflating: transcript/final text/M53N25.ort
#   inflating: transcript/final text/M53N26.ort
#   inflating: transcript/final text/M53N27.ort
#   inflating: transcript/final text/M53S01.ort
#   inflating: transcript/final text/M53S02.ort
#   inflating: transcript/final text/M54A01.ort
#   inflating: transcript/final text/M54N02.ort
#   inflating: transcript/final text/M54N03.ort
#   inflating: transcript/final text/M54N04.ort
#   inflating: transcript/final text/M54S01.ort
#   inflating: transcript/final text/M55A01.ort
#   inflating: transcript/final text/M55A02.ort
#   inflating: transcript/final text/M55A03.ort
#   inflating: transcript/final text/M55A04.ort
#   inflating: transcript/final text/M55H01.ort
#   inflating: transcript/final text/M55N01.ort
#   inflating: transcript/final text/M55N02.ort
#   inflating: transcript/final text/M55N03.ort
#   inflating: transcript/final text/M55N04.ort
#   inflating: transcript/final text/M55N05.ort
#   inflating: transcript/final text/M55N06.ort
#   inflating: transcript/final text/M56A01.ort
#   inflating: transcript/final text/M56N01.ort
#   inflating: transcript/final text/M56N02.ort
#   inflating: transcript/final text/M56N03.ort
#   inflating: transcript/final text/M56N04.ort
#   inflating: transcript/final text/M56N05.ort
#   inflating: transcript/final text/M56W01.ort

# %%
# !mkdir dataset
# !mv female dataset
# !mv male dataset

# %%
import os
import pandas as pd
# Path to your dataset folders (male and fema|le)
male_folder = '/content/dataset/male'
female_folder = '/content/dataset/female'

# Dictionary to store information
data_info = {
    'male': [],
    'female': []
}

# Function to extract information from the file names
def extract_info(file_path):
    file_info = {}
    filename = os.path.basename(file_path)  # Extract filename from the path
    file_info['gender'] = filename[0]  # Extracting the gender (M or F)
    file_info['speaker_code'] = filename[1:3]  # Extracting the speaker code
    file_info['emotion'] = filename[3]  # Extracting the emotion code
    file_info['utterance_number'] = filename[4:]  # Extracting the utterance number
    file_info['path'] = file_path  # Storing the complete file path
    return file_info

data = []

# Process male folder
for filename in os.listdir(male_folder):
    file_path = os.path.join(male_folder, filename)
    file_info = extract_info(file_path)
    data.append(file_info)

# Process female folder
for filename in os.listdir(female_folder):
    file_path = os.path.join(female_folder, filename)
    file_info = extract_info(file_path)
    data.append(file_info)

# Create a DataFrame from the collected data
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#      gender speaker_code emotion utterance_number  \
# 0         M           06       N           04.wav
# 1         M           25       N           15.wav
# 2         M           16       W           02.wav
# 3         M           05       N           18.wav
# 4         M           05       N           02.wav
# ...     ...          ...     ...              ...
# 2995      F           28       A           23.wav
# 2996      F           12       N           09.wav
# 2997      F           21       W           31.wav
# 2998      F           21       H           11.wav
# 2999      F           07       A           44.wav
#
#                                     path
# 0       /content/dataset/male/M06N04.wav
# 1       /content/dataset/male/M25N15.wav
# 2       /content/dataset/male/M16W02.wav
# 3       /content/dataset/male/M05N18.wav
# 4       /content/dataset/male/M05N02.wav
# ...                                  ...
# 2995  /content/dataset/female/F28A23.wav
# 2996  /content/dataset/female/F12N09.wav
# 2997  /content/dataset/female/F21W31.wav
# 2998  /content/dataset/female/F21H11.wav
# 2999  /content/dataset/female/F07A44.wav
#
# [3000 rows x 5 columns]

# %%
import librosa

# Function to calculate duration in seconds for an audio file
def get_duration(file_path):
    audio, sr = librosa.load(file_path)
    duration_sec = librosa.get_duration(y=audio, sr=sr)
    return duration_sec

# Assuming 'df' contains a column named 'path' with file paths
# Add a new column 'duration_sec' to store voice durations
df['duration_sec'] = df['path'].apply(lambda x: get_duration(x))

# %% [markdown]
# # Data viz

# %%
df.head()
# Out:
#   gender speaker_code emotion utterance_number  \
# 0      M           06       N           04.wav
# 1      M           25       N           15.wav
# 2      M           16       W           02.wav
# 3      M           05       N           18.wav
# 4      M           05       N           02.wav
#
#                                path  duration_sec
# 0  /content/dataset/male/M06N04.wav      1.082676
# 1  /content/dataset/male/M25N15.wav      6.294694
# 2  /content/dataset/male/M16W02.wav      0.979138
# 3  /content/dataset/male/M05N18.wav      3.016508
# 4  /content/dataset/male/M05N02.wav      1.577052

# %%
df.describe(include='all')
# Out:
#        gender speaker_code emotion utterance_number  \
# count    3000         3000    3000             3000
# unique      2           56       6               87
# top         M           12       A           01.wav
# freq     1737          208    1059              341
# mean      NaN          NaN     NaN              NaN
# std       NaN          NaN     NaN              NaN
# min       NaN          NaN     NaN              NaN
# 25%       NaN          NaN     NaN              NaN
# 50%       NaN          NaN     NaN              NaN
# 75%       NaN          NaN     NaN              NaN
# max       NaN          NaN     NaN              NaN
#
#                                       path  duration_sec
# count                                 3000   3000.000000
# unique                                3000           NaN
# top     /content/dataset/female/F07A44.wav           NaN
# freq                                     1           NaN
# mean                                   NaN      4.111807
# std                                    NaN      3.414900
# min                                    NaN      0.358639
# 25%                                    NaN      1.955113
# 50%                                    NaN      3.079637
# 75%                                    NaN      5.104093
# max                                    NaN     33.328027

# %%
# Value counts for the 'gender' column
gender_counts = df['gender'].value_counts()

# Display the value counts for gender
print(gender_counts)
# Out:
# gender
# M    1737
# F    1263
# Name: count, dtype: int64

# %%
# Value counts for the 'gender' column
gender_counts = df['emotion'].value_counts()

# Display the value counts for gender
print(gender_counts)
# Out:
# emotion
# A    1059
# N    1028
# S     449
# W     225
# H     201
# F      38
# Name: count, dtype: int64

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('emotion').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# Assuming 'df' contains your DataFrame with columns 'gender' and 'emotion'

# Grouping by 'gender' and 'emotion', then counting occurrences
grouped = df.groupby(['gender', 'emotion']).size().reset_index(name='count')

# Plotting the grouped bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x='count', y='emotion', hue='gender', data=grouped, palette='Dark2')

# Removing the spines (top and right)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adding labels and title
plt.xlabel('Count')
plt.ylabel('Emotion')
plt.title('Count of Emotions by Gender')

plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting a histogram of durations
plt.figure(figsize=(8, 6))
plt.hist(df['duration_sec'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Duration (seconds)')
plt.ylabel('Frequency')
plt.title('Distribution of Audio File Durations')
plt.show()

# %%
import seaborn as sns

# Boxplot of duration by emotion
plt.figure(figsize=(10, 6))
sns.boxplot(x='emotion', y='duration_sec', data=df, palette='Set2')
plt.xlabel('Emotion')
plt.ylabel('Duration (seconds)')
plt.title('Duration of Audio Files by Emotion')
plt.show()
# Out:
# <ipython-input-14-5ac246d5e1cc>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='emotion', y='duration_sec', data=df, palette='Set2')

# %%
# Boxplot of duration by gender
plt.figure(figsize=(8, 6))
sns.boxplot(x='gender', y='duration_sec', data=df, palette='Pastel1')
plt.xlabel('Gender')
plt.ylabel('Duration (seconds)')
plt.title('Duration of Audio Files by Gender')
plt.show()
# Out:
# <ipython-input-15-df8741574bfb>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='duration_sec', data=df, palette='Pastel1')

# %% [markdown]
# # Fine-tune pre-trained model

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['labels'] = label_encoder.fit_transform(df['emotion'])

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'df' contains your DataFrame with 'emotion' as the target column
# Splitting the data into train (60%), validation (20%), and test (20%) while preserving the distribution of 'emotion'
train_df, test_val_df = train_test_split(df, test_size=0.4, stratify=df['emotion'])
test_df, val_df = train_test_split(test_val_df, test_size=0.5, stratify=test_val_df['emotion'])

# Get unique emotions
emotions = df['emotion'].unique()
num_emotions = len(emotions)

# Calculate emotion counts in train, validation, and test datasets
train_emotion_counts = train_df['emotion'].value_counts().reindex(emotions, fill_value=0)
test_emotion_counts = test_df['emotion'].value_counts().reindex(emotions, fill_value=0)
val_emotion_counts = val_df['emotion'].value_counts().reindex(emotions, fill_value=0)

# Set the positions for bars
bar_width = 0.25
index = np.arange(num_emotions)

# Plotting the distribution of emotions in train, validation, and test datasets side by side
plt.figure(figsize=(10, 6))
plt.bar(index, train_emotion_counts.values, alpha=0.7, label='Train', width=bar_width)
plt.bar(index + bar_width, test_emotion_counts.values, alpha=0.7, label='Test', width=bar_width)
plt.bar(index + 2 * bar_width, val_emotion_counts.values, alpha=0.7, label='Val', width=bar_width)

plt.xlabel('Emotion')
plt.ylabel('Count')
plt.title('Distribution of Emotions in Train, Validation, and Test Datasets')
plt.xticks(index + bar_width, emotions)  # Set x-axis labels
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## HuBert base

# %%
# Define the map_to_array function
from transformers import Wav2Vec2FeatureExtractor
from datasets import Dataset
import librosa
def map_to_array(example):
    speech, _ = librosa.load(example["path"], sr=16000, mono=True)
    example["speech"] = speech
    return example

# Assuming train_df, test_df, val_df are pandas DataFrames with 'path' and 'labels' columns
train_data = Dataset.from_pandas(train_df).map(map_to_array)
test_data = Dataset.from_pandas(test_df).map(map_to_array)
val_data = Dataset.from_pandas(val_df).map(map_to_array)

# Preprocessing function to extract features
def preprocess_function(examples):
    audio = examples["speech"]
    inputs = feature_extractor(audio, sampling_rate=16000, padding=True, truncation=True,max_length=16000)
    inputs["labels"] = examples["labels"]
    return inputs

# Apply preprocessing
feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("facebook/hubert-base-ls960")

train_encodings = train_data.map(preprocess_function, remove_columns="speech", batched=True)
test_encodings = test_data.map(preprocess_function, remove_columns="speech", batched=True)
val_encodings = val_data.map(preprocess_function, remove_columns="speech", batched=True)

train_dataset = train_encodings.with_format("torch")
test_dataset = test_encodings.with_format("torch")
val_dataset = val_encodings.with_format("torch")
# Out:
# Map:   0%|          | 0/1800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/213 [00:00<?, ?B/s]
# Map:   0%|          | 0/1800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]

# %%
# Define the model
from transformers import Wav2Vec2FeatureExtractor, Wav2Vec2ForSequenceClassification, TrainingArguments, Trainer, TrainerCallback
from datasets import Dataset, load_metric
import pandas as pd
import torch
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay


num_labels=6
# Define the model
model = Wav2Vec2ForSequenceClassification.from_pretrained("facebook/hubert-base-ls960", num_labels=num_labels)

# Custom callback to log metrics
class LoggingCallback(TrainerCallback):
    def __init__(self):
        self.train_loss = []
        self.eval_loss = []
        self.train_acc = []
        self.eval_acc = []

    def on_log(self, args, state, control, logs=None, **kwargs):
        if "loss" in logs:
            self.train_loss.append(logs["loss"])
        if "eval_loss" in logs:
            self.eval_loss.append(logs["eval_loss"])
        if "eval_accuracy" in logs:
            self.eval_acc.append(logs["eval_accuracy"])
        if "accuracy" in logs:
            self.train_acc.append(logs["accuracy"])

# Initialize the custom callback

# Define accuracy metric
accuracy_metric = load_metric("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return accuracy_metric.compute(predictions=predictions, references=labels)

# Initialize the custom callback
logging_callback = LoggingCallback()

# Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    per_device_train_batch_size=64,
    per_device_eval_batch_size=64,
    num_train_epochs=10,
    logging_dir="./logs",
    logging_steps=10,
)

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics,
    callbacks=[logging_callback],
)
# Training
trainer.train()

# Evaluation
trainer.evaluate(test_dataset)

# Plotting loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(logging_callback.train_loss, label="Train Loss")
plt.plot(logging_callback.eval_loss, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(logging_callback.train_acc, label="Train Accuracy")
plt.plot(logging_callback.eval_acc, label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()

plt.show()
# Out:
# You are using a model of type hubert to instantiate a model of type wav2vec2. This is not supported for all configurations of models and can yield errors.
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at facebook/hubert-base-ls960 and are newly initialized: ['classifier.bias', 'classifier.weight', 'encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='290' max='290' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [290/290 04:34, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.512100</td>
#       <td>1.459787</td>
#       <td>0.341667</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.432000</td>
#       <td>1.453544</td>
#       <td>0.353333</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.434900</td>
#       <td>1.397093</td>
#       <td>0.471667</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.348800</td>
#       <td>1.357576</td>
#       <td>0.511667</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.297300</td>
#       <td>1.354131</td>
#       <td>0.531667</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.301600</td>
#       <td>1.298284</td>
#       <td>0.548333</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.229700</td>
#       <td>1.330421</td>
#       <td>0.536667</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.262000</td>
#       <td>1.350470</td>
#       <td>0.530000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.257100</td>
#       <td>1.378565</td>
#       <td>0.521667</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.198700</td>
#       <td>1.326682</td>
#       <td>0.548333</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 00:02]
#     </div>

# %%
# Make predictions on the test set
predictions = trainer.predict(test_dataset)
preds = np.argmax(predictions.predictions, axis=-1)

# Generate classification report
report = classification_report(test_dataset["labels"], preds)
print("Classification Report:\n", report)

# Generate confusion matrix
cm = confusion_matrix(test_dataset["labels"], preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.48      0.90      0.62       212
#            1       0.00      0.00      0.00         7
#            2       0.00      0.00      0.00        40
#            3       0.70      0.69      0.70       206
#            4       0.00      0.00      0.00        90
#            5       0.00      0.00      0.00        45
#
#     accuracy                           0.55       600
#    macro avg       0.20      0.26      0.22       600
# weighted avg       0.41      0.55      0.46       600

# %% [markdown]
# ## HuBert er

# %%
# Define the map_to_array function
from transformers import Wav2Vec2FeatureExtractor
from datasets import Dataset
import librosa
def map_to_array(example):
    speech, _ = librosa.load(example["path"], sr=16000, mono=True)
    example["speech"] = speech
    return example

# Assuming train_df, test_df, val_df are pandas DataFrames with 'path' and 'labels' columns
train_data = Dataset.from_pandas(train_df).map(map_to_array)
test_data = Dataset.from_pandas(test_df).map(map_to_array)
val_data = Dataset.from_pandas(val_df).map(map_to_array)

# Preprocessing function to extract features
def preprocess_function(examples):
    audio = examples["speech"]
    inputs = feature_extractor(audio, sampling_rate=16000, padding=True, truncation=True,max_length=16000)
    inputs["labels"] = examples["labels"]
    return inputs

# Apply preprocessing
feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("superb/hubert-base-superb-er")

train_encodings = train_data.map(preprocess_function, remove_columns="speech", batched=True)
test_encodings = test_data.map(preprocess_function, remove_columns="speech", batched=True)
val_encodings = val_data.map(preprocess_function, remove_columns="speech", batched=True)

train_dataset = train_encodings.with_format("torch")
test_dataset = test_encodings.with_format("torch")
val_dataset = val_encodings.with_format("torch")
# Out:
# Map:   0%|          | 0/1800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/213 [00:00<?, ?B/s]
# Map:   0%|          | 0/1800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]

# %%
# Define the model
from transformers import Wav2Vec2FeatureExtractor, Wav2Vec2ForSequenceClassification, TrainingArguments, Trainer, TrainerCallback
from datasets import Dataset, load_metric
import pandas as pd
import torch
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay


num_labels=6
# Define the model
model = Wav2Vec2ForSequenceClassification.from_pretrained("superb/hubert-base-superb-er", num_labels=num_labels)

# Custom callback to log metrics
class LoggingCallback(TrainerCallback):
    def __init__(self):
        self.train_loss = []
        self.eval_loss = []
        self.train_acc = []
        self.eval_acc = []

    def on_log(self, args, state, control, logs=None, **kwargs):
        if "loss" in logs:
            self.train_loss.append(logs["loss"])
        if "eval_loss" in logs:
            self.eval_loss.append(logs["eval_loss"])
        if "eval_accuracy" in logs:
            self.eval_acc.append(logs["eval_accuracy"])
        if "accuracy" in logs:
            self.train_acc.append(logs["accuracy"])

# Initialize the custom callback

# Define accuracy metric
accuracy_metric = load_metric("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return accuracy_metric.compute(predictions=predictions, references=labels)

# Initialize the custom callback
logging_callback = LoggingCallback()

# Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    per_device_train_batch_size=64,
    per_device_eval_batch_size=64,
    num_train_epochs=10,
    logging_dir="./logs",
    logging_steps=10,
)

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics,
    callbacks=[logging_callback],
)
# Training
trainer.train()

# Evaluation
trainer.evaluate(test_dataset)

# Plotting loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(logging_callback.train_loss, label="Train Loss")
plt.plot(logging_callback.eval_loss, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(logging_callback.train_acc, label="Train Accuracy")
plt.plot(logging_callback.eval_acc, label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()

plt.show()
# Out:
# You are using a model of type hubert to instantiate a model of type wav2vec2. This is not supported for all configurations of models and can yield errors.
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at facebook/hubert-base-ls960 and are newly initialized: ['classifier.bias', 'classifier.weight', 'encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'projector.bias', 'projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='290' max='290' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [290/290 04:34, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.512100</td>
#       <td>1.459787</td>
#       <td>0.341667</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.432000</td>
#       <td>1.453544</td>
#       <td>0.353333</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.434900</td>
#       <td>1.397093</td>
#       <td>0.471667</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.348800</td>
#       <td>1.357576</td>
#       <td>0.511667</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.297300</td>
#       <td>1.354131</td>
#       <td>0.531667</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.301600</td>
#       <td>1.298284</td>
#       <td>0.548333</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.229700</td>
#       <td>1.330421</td>
#       <td>0.536667</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.262000</td>
#       <td>1.350470</td>
#       <td>0.530000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.257100</td>
#       <td>1.378565</td>
#       <td>0.521667</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.198700</td>
#       <td>1.326682</td>
#       <td>0.548333</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 00:02]
#     </div>

# %%
# Make predictions on the test set
predictions = trainer.predict(test_dataset)
preds = np.argmax(predictions.predictions, axis=-1)

# Generate classification report
report = classification_report(test_dataset["labels"], preds)
print("Classification Report:\n", report)

# Generate confusion matrix
cm = confusion_matrix(test_dataset["labels"], preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.48      0.90      0.62       212
#            1       0.00      0.00      0.00         7
#            2       0.00      0.00      0.00        40
#            3       0.70      0.69      0.70       206
#            4       0.00      0.00      0.00        90
#            5       0.00      0.00      0.00        45
#
#     accuracy                           0.55       600
#    macro avg       0.20      0.26      0.22       600
# weighted avg       0.41      0.55      0.46       600

# %% [markdown]
# ## Wav2vec er english

# %%
# Define the map_to_array function
from transformers import Wav2Vec2FeatureExtractor
from datasets import Dataset
import librosa
def map_to_array(example):
    speech, _ = librosa.load(example["path"], sr=16000, mono=True)
    example["speech"] = speech
    return example

# Assuming train_df, test_df, val_df are pandas DataFrames with 'path' and 'labels' columns
train_data = Dataset.from_pandas(train_df).map(map_to_array)
test_data = Dataset.from_pandas(test_df).map(map_to_array)
val_data = Dataset.from_pandas(val_df).map(map_to_array)

# Preprocessing function to extract features
def preprocess_function(examples):
    audio = examples["speech"]
    inputs = feature_extractor(audio, sampling_rate=16000, padding=True, truncation=True,max_length=16000)
    inputs["labels"] = examples["labels"]
    return inputs

# Apply preprocessing
feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("r-f/wav2vec-english-speech-emotion-recognition")

train_encodings = train_data.map(preprocess_function, remove_columns="speech", batched=True)
test_encodings = test_data.map(preprocess_function, remove_columns="speech", batched=True)
val_encodings = val_data.map(preprocess_function, remove_columns="speech", batched=True)

train_dataset = train_encodings.with_format("torch")
test_dataset = test_encodings.with_format("torch")
val_dataset = val_encodings.with_format("torch")
# Out:
# Map:   0%|          | 0/1800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]
# preprocessor_config.json:   0%|          | 0.00/262 [00:00<?, ?B/s]
# Map:   0%|          | 0/1800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]

# %%
# Define the model
from transformers import Wav2Vec2FeatureExtractor, Wav2Vec2ForSequenceClassification, TrainingArguments, Trainer, TrainerCallback
from datasets import Dataset, load_metric
import pandas as pd
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
from transformers import HubertModel
import torch
import torch.nn as nn
import numpy as np
from transformers import HubertModel, Trainer, TrainingArguments
from datasets import load_metric

num_labels=6
model = Wav2Vec2ForSequenceClassification.from_pretrained("r-f/wav2vec-english-speech-emotion-recognition", num_labels=num_labels)

# Custom callback to log metrics
class LoggingCallback(TrainerCallback):
    def __init__(self):
        self.train_loss = []
        self.eval_loss = []
        self.train_acc = []
        self.eval_acc = []

    def on_log(self, args, state, control, logs=None, **kwargs):
        if "loss" in logs:
            self.train_loss.append(logs["loss"])
        if "eval_loss" in logs:
            self.eval_loss.append(logs["eval_loss"])
        if "eval_accuracy" in logs:
            self.eval_acc.append(logs["eval_accuracy"])
        if "train_accuracy" in logs:
            self.train_acc.append(logs["train_accuracy"])

# Initialize the custom callback

# Define accuracy metric
accuracy_metric = load_metric("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return accuracy_metric.compute(predictions=predictions, references=labels)

# Initialize the custom callback
logging_callback = LoggingCallback()

# Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    per_device_train_batch_size=64,
    per_device_eval_batch_size=64,
    num_train_epochs=10,
    logging_dir="./logs",
    logging_steps=10,
)

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics,
    callbacks=[logging_callback],
)
# Training
trainer.train()

# Evaluation
trainer.evaluate(test_dataset)

# Plotting loss and accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(logging_callback.train_loss, label="Train Loss")
plt.plot(logging_callback.eval_loss, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(logging_callback.train_acc, label="Train Accuracy")
plt.plot(logging_callback.eval_acc, label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()

plt.show()
# Out:
# config.json:   0%|          | 0.00/2.71k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at r-f/wav2vec-english-speech-emotion-recognition and are newly initialized: ['classifier.bias', 'classifier.weight', 'projector.bias', 'projector.weight', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     <div>
#
#       <progress value='290' max='290' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [290/290 11:25, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.423400</td>
#       <td>1.225796</td>
#       <td>0.605000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.100700</td>
#       <td>1.050840</td>
#       <td>0.653333</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.964100</td>
#       <td>0.943391</td>
#       <td>0.681667</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.871900</td>
#       <td>0.891010</td>
#       <td>0.691667</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.868800</td>
#       <td>0.886784</td>
#       <td>0.703333</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.768000</td>
#       <td>0.834982</td>
#       <td>0.730000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.778400</td>
#       <td>0.840871</td>
#       <td>0.723333</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.706800</td>
#       <td>0.807615</td>
#       <td>0.740000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.714300</td>
#       <td>0.800797</td>
#       <td>0.745000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.650000</td>
#       <td>0.801681</td>
#       <td>0.735000</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 00:06]
#     </div>

# %%
# Make predictions on the test set
predictions = trainer.predict(test_dataset)
preds = np.argmax(predictions.predictions, axis=-1)

# Generate classification report
report = classification_report(test_dataset["labels"], preds)
print("Classification Report:\n", report)

# Generate confusion matrix
cm = confusion_matrix(test_dataset["labels"], preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84       212
#            1       0.00      0.00      0.00         7
#            2       0.73      0.20      0.31        40
#            3       0.67      0.90      0.77       206
#            4       0.56      0.61      0.59        90
#            5       0.71      0.11      0.19        45
#
#     accuracy                           0.71       600
#    macro avg       0.59      0.44      0.45       600
# weighted avg       0.72      0.71      0.68       600

# %% [markdown]
# # Classic Machine Learning

# %%
import librosa
import numpy as np

def extract_features(file_path, mfcc=True, chroma=True, mel=True):
    with open(file_path, 'rb') as f:
        try:
            audio, sr = librosa.load(f)
            features = []
            if mfcc:
                mfccs = np.mean(librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13).T, axis=0)
                features.extend(mfccs)
            if chroma:
                chroma = np.mean(librosa.feature.chroma_stft(y=audio, sr=sr).T, axis=0)
                features.extend(chroma)
            if mel:
                mel = np.mean(librosa.feature.melspectrogram(y=audio, sr=sr).T, axis=0)
                features.extend(mel)
        except Exception as e:
            print(f"Error encountered while parsing file: {file_path}")
            return None

    return features

# %%
# Load data for training, validation, and testing
def load_data_from_df(df):
    X = []
    y = []
    for index, row in df.iterrows():
        file_path = row['path']  # Assuming 'file_path' is the column name for audio file paths
        emotion_label = row['emotion']  # Assuming 'emotion' is the column name for emotion labels
        features = extract_features(file_path)
        if features is not None:
            X.append(features)
            y.append(emotion_label)
    return X, y
X_train, y_train = load_data_from_df(train_df)
X_val, y_val = load_data_from_df(val_df)
X_test, y_test = load_data_from_df(test_df)

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
# Initialize SVM classifier
svm_model = SVC(kernel='linear', random_state=42)

# Train SVM model
svm_model.fit(X_train, y_train)

# Predict on test set
y_pred_test = svm_model.predict(X_test)

# Evaluate test accuracy
test_accuracy = accuracy_score(y_test, y_pred_test)
print(f"Test Accuracy: {test_accuracy}")

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_test))

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=svm_model.classes_, yticklabels=svm_model.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Test Accuracy: 0.6666666666666666
# Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.78      0.82      0.80       212
#            F       0.08      0.14      0.11         7
#            H       0.12      0.07      0.09        40
#            N       0.71      0.80      0.75       206
#            S       0.58      0.46      0.51        90
#            W       0.44      0.38      0.40        45
#
#     accuracy                           0.67       600
#    macro avg       0.45      0.44      0.44       600
# weighted avg       0.65      0.67      0.65       600

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# Initialize Logistic Regression classifier
logreg_model = LogisticRegression(max_iter=1000, random_state=42)

# Train Logistic Regression model
logreg_model.fit(X_train, y_train)

# Predict on test set
y_pred_logreg = logreg_model.predict(X_test)

# Evaluate test accuracy
test_accuracy_logreg = accuracy_score(y_test, y_pred_logreg)
print(f"Logistic Regression Test Accuracy: {test_accuracy_logreg}")

# Generate classification report for Logistic Regression
print("Logistic Regression Classification Report:")
print(classification_report(y_test, y_pred_logreg))

# Generate confusion matrix for Logistic Regression
conf_matrix_logreg = confusion_matrix(y_test, y_pred_logreg)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix_logreg, annot=True, fmt='d', cmap='Blues', xticklabels=logreg_model.classes_, yticklabels=logreg_model.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Logistic Regression Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Test Accuracy: 0.6733333333333333
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.78      0.80      0.79       212
#            F       0.00      0.00      0.00         7
#            H       0.21      0.07      0.11        40
#            N       0.70      0.80      0.75       206
#            S       0.54      0.62      0.58        90
#            W       0.42      0.22      0.29        45
#
#     accuracy                           0.67       600
#    macro avg       0.44      0.42      0.42       600
# weighted avg       0.64      0.67      0.65       600

# %% [markdown]
# ## naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# Initialize Gaussian Naive Bayes classifier
nb_model = GaussianNB()

# Train Naive Bayes model
nb_model.fit(X_train, y_train)

# Predict on test set
y_pred_nb = nb_model.predict(X_test)

# Evaluate test accuracy
test_accuracy_nb = accuracy_score(y_test, y_pred_nb)
print(f"Naive Bayes Test Accuracy: {test_accuracy_nb}")

# Generate classification report for Naive Bayes
print("Naive Bayes Classification Report:")
print(classification_report(y_test, y_pred_nb))

# Generate confusion matrix for Naive Bayes
conf_matrix_nb = confusion_matrix(y_test, y_pred_nb)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix_nb, annot=True, fmt='d', cmap='Blues', xticklabels=nb_model.classes_, yticklabels=nb_model.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Naive Bayes Confusion Matrix')
plt.show()
# Out:
# Naive Bayes Test Accuracy: 0.55
# Naive Bayes Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.85      0.60      0.70       212
#            F       0.04      0.14      0.06         7
#            H       0.10      0.20      0.14        40
#            N       0.56      0.81      0.67       206
#            S       0.52      0.17      0.25        90
#            W       0.48      0.27      0.34        45
#
#     accuracy                           0.55       600
#    macro avg       0.43      0.36      0.36       600
# weighted avg       0.62      0.55      0.55       600

# %% [markdown]
# ## Simple Neural network

# %%
# Normalize features (optional but recommended for neural networks)
import librosa
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import seaborn as sns

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test =label_encoder.transform(y_test)
y_val =label_encoder.transform(y_val)

# Build a neural network model
model = Sequential([
    Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(np.unique(y_train)), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()

# Train the model
history = model.fit(X_train, y_train,
                    epochs=50,
                    batch_size=32,
                    validation_data=(X_val, y_val),
                    verbose=1)

# Evaluate the model on test set
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy}")

# Predict on test set
y_pred_nn = np.argmax(model.predict(X_test), axis=-1)

# Generate classification report for Neural Network
print("Neural Network Classification Report:")
print(classification_report(y_test, y_pred_nn))

# Generate confusion matrix for Neural Network
conf_matrix_nn = confusion_matrix(y_test, y_pred_nn)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix_nn, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Neural Network Confusion Matrix')
plt.show()

# Plot training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 256)               39424
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 73094 (285.52 KB)
# Trainable params: 73094 (285.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 57/57 [==============================] - 1s 8ms/step - loss: 1.4738 - accuracy: 0.5139 - val_loss: 1.1140 - val_accuracy: 0.6400
# Epoch 2/50
# 57/57 [==============================] - 0s 4ms/step - loss: 1.2094 - accuracy: 0.6161 - val_loss: 1.0612 - val_accuracy: 0.6567
# Epoch 3/50
# 57/57 [==============================] - 0s 5ms/step - loss: 1.1388 - accuracy: 0.6183 - val_loss: 1.0098 - val_accuracy: 0.6767
# Epoch 4/50
# 57/57 [==============================] - 0s 5ms/step - loss: 1.0745 - accuracy: 0.6467 - val_loss: 1.0063 - val_accuracy: 0.6700
# Epoch 5/50
# 57/57 [==============================] - 0s 5ms/step - loss: 1.0184 - accuracy: 0.6600 - val_loss: 0.9916 - val_accuracy: 0.6783
# Epoch 6/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.9843 - accuracy: 0.6639 - val_loss: 1.0024 - val_accuracy: 0.6667
# Epoch 7/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.9317 - accuracy: 0.6728 - val_loss: 0.9688 - val_accuracy: 0.6850
# Epoch 8/50
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8905 - accuracy: 0.6911 - val_loss: 0.9705 - val_accuracy: 0.6917
# Epoch 9/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8675 - accuracy: 0.6944 - val_loss: 0.9577 - val_accuracy: 0.6933
# Epoch 10/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8625 - accuracy: 0.7006 - val_loss: 0.9670 - val_accuracy: 0.6983
# Epoch 11/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8308 - accuracy: 0.7122 - val_loss: 0.9475 - val_accuracy: 0.6800
# Epoch 12/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.8116 - accuracy: 0.7222 - val_loss: 0.9494 - val_accuracy: 0.6800
# Epoch 13/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.7743 - accuracy: 0.7183 - val_loss: 0.9404 - val_accuracy: 0.6917
# Epoch 14/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.7725 - accuracy: 0.7283 - val_loss: 0.9633 - val_accuracy: 0.6800
# Epoch 15/50
# 57/57 [==============================] - 0s 7ms/step - loss: 0.7286 - accuracy: 0.7356 - val_loss: 0.9612 - val_accuracy: 0.6967
# Epoch 16/50
# 57/57 [==============================] - 0s 7ms/step - loss: 0.7506 - accuracy: 0.7317 - val_loss: 0.9757 - val_accuracy: 0.6950
# Epoch 17/50
# 57/57 [==============================] - 0s 7ms/step - loss: 0.7057 - accuracy: 0.7506 - val_loss: 0.9755 - val_accuracy: 0.6917
# Epoch 18/50
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6940 - accuracy: 0.7467 - val_loss: 0.9794 - val_accuracy: 0.6983
# Epoch 19/50
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6864 - accuracy: 0.7539 - val_loss: 0.9549 - val_accuracy: 0.6883
# Epoch 20/50
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6739 - accuracy: 0.7572 - val_loss: 0.9636 - val_accuracy: 0.6983
# Epoch 21/50
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6299 - accuracy: 0.7711 - val_loss: 0.9910 - val_accuracy: 0.7033
# Epoch 22/50
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6550 - accuracy: 0.7622 - val_loss: 0.9854 - val_accuracy: 0.6983
# Epoch 23/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6137 - accuracy: 0.7794 - val_loss: 0.9929 - val_accuracy: 0.6950
# Epoch 24/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.5984 - accuracy: 0.7867 - val_loss: 1.0198 - val_accuracy: 0.7017
# Epoch 25/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6094 - accuracy: 0.7828 - val_loss: 1.0307 - val_accuracy: 0.7083
# Epoch 26/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5700 - accuracy: 0.8094 - val_loss: 1.0279 - val_accuracy: 0.7067
# Epoch 27/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5717 - accuracy: 0.8011 - val_loss: 1.0673 - val_accuracy: 0.7083
# Epoch 28/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5611 - accuracy: 0.8122 - val_loss: 1.0500 - val_accuracy: 0.7150
# Epoch 29/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5354 - accuracy: 0.8106 - val_loss: 1.0854 - val_accuracy: 0.6933
# Epoch 30/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5254 - accuracy: 0.8133 - val_loss: 1.0421 - val_accuracy: 0.6967
# Epoch 31/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5135 - accuracy: 0.8022 - val_loss: 1.1023 - val_accuracy: 0.6967
# Epoch 32/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5316 - accuracy: 0.8089 - val_loss: 1.0800 - val_accuracy: 0.6967
# Epoch 33/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4996 - accuracy: 0.8244 - val_loss: 1.0717 - val_accuracy: 0.6967
# Epoch 34/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5088 - accuracy: 0.8206 - val_loss: 1.0969 - val_accuracy: 0.6983
# Epoch 35/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4971 - accuracy: 0.8294 - val_loss: 1.1334 - val_accuracy: 0.7000
# Epoch 36/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4932 - accuracy: 0.8294 - val_loss: 1.0926 - val_accuracy: 0.7017
# Epoch 37/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4892 - accuracy: 0.8256 - val_loss: 1.1003 - val_accuracy: 0.6967
# Epoch 38/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4930 - accuracy: 0.8250 - val_loss: 1.0793 - val_accuracy: 0.7100
# Epoch 39/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4419 - accuracy: 0.8411 - val_loss: 1.0923 - val_accuracy: 0.7083
# Epoch 40/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4545 - accuracy: 0.8322 - val_loss: 1.1300 - val_accuracy: 0.7067
# Epoch 41/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4536 - accuracy: 0.8372 - val_loss: 1.1583 - val_accuracy: 0.7017
# Epoch 42/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4169 - accuracy: 0.8528 - val_loss: 1.1582 - val_accuracy: 0.7000
# Epoch 43/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4280 - accuracy: 0.8439 - val_loss: 1.1878 - val_accuracy: 0.7083
# Epoch 44/50
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4121 - accuracy: 0.8622 - val_loss: 1.2333 - val_accuracy: 0.7050
# Epoch 45/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4187 - accuracy: 0.8578 - val_loss: 1.2394 - val_accuracy: 0.7050
# Epoch 46/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3813 - accuracy: 0.8567 - val_loss: 1.2721 - val_accuracy: 0.6933
# Epoch 47/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3978 - accuracy: 0.8528 - val_loss: 1.2514 - val_accuracy: 0.7033
# Epoch 48/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3548 - accuracy: 0.8744 - val_loss: 1.3040 - val_accuracy: 0.7000
# Epoch 49/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3741 - accuracy: 0.8672 - val_loss: 1.2897 - val_accuracy: 0.6967
# Epoch 50/50
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3929 - accuracy: 0.8589 - val_loss: 1.2969 - val_accuracy: 0.7117
# Test Accuracy: 0.699999988079071
# 19/19 [==============================] - 0s 2ms/step
# Neural Network Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81       212
#            1       0.00      0.00      0.00         7
#            2       0.27      0.10      0.15        40
#            3       0.73      0.83      0.78       206
#            4       0.58      0.58      0.58        90
#            5       0.42      0.36      0.39        45
#
#     accuracy                           0.70       600
#    macro avg       0.47      0.45      0.45       600
# weighted avg       0.67      0.70      0.68       600
